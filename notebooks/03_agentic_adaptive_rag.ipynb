# %% [markdown]
# # Agentic Adaptive RAG with LangGraph
#
# In this notebook, we'll build the most sophisticated RAG system yet - one that adapts its strategy based on query complexity, evaluates result quality, and can even rewrite queries for better results.
#
# ## What is Adaptive RAG?
#
# Adaptive RAG goes beyond simple routing by:
# 1. **Analyzing query complexity** to determine the best retrieval strategy
# 2. **Searching multiple collections** when queries span domains
# 3. **Evaluating result quality** and adapting if results are poor
# 4. **Rewriting queries** to improve retrieval when needed
# 5. **Self-correcting** through iterative refinement
#
# ## Learning Objectives
#
# By the end of this notebook, you will:
# - Understand query complexity analysis and strategy selection
# - Build multi-collection search capabilities
# - Implement response quality evaluation and grading
# - Create query rewriting and expansion mechanisms
# - Design self-correcting RAG workflows
# - Compare adaptive RAG with simpler approaches

# %% [markdown]
# ## Setup and Imports
#
# We'll need additional imports for the adaptive functionality.

# %%
import os
from pathlib import Path
from typing import List, TypedDict, Literal, Optional, Tuple, Dict
import time
from collections import defaultdict

from dotenv import load_dotenv
from langchain_chroma import Chroma
from langchain_core.documents import Document
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_tavily import TavilySearch
from langgraph.graph import StateGraph, START, END
from pydantic import BaseModel, Field
from IPython.display import Image, display

# Load environment variables
load_dotenv()

print("All imports successful!")
# Out:
# All imports successful!

# %%
# Parallel Logger for handling print statements in parallel execution
class ParallelLogger:
    """Buffered logger for organizing print statements during parallel execution."""
    
    def __init__(self, task_id: str):
        self.task_id = task_id
        self.logs = []
        self.start_time = time.time()
    
    def log(self, message: str, level: str = "INFO"):
        """Log a message with timestamp."""
        timestamp = time.time() - self.start_time
        self.logs.append({
            "timestamp": timestamp,
            "level": level,
            "message": message
        })
    
    def get_logs(self) -> List[dict]:
        """Get all logged messages."""
        return self.logs
    
    def print_logs(self, prefix: str = ""):
        """Print all logged messages in order."""
        for entry in self.logs:
            print(f"{prefix}[{entry['timestamp']:.2f}s] {entry['message']}")

class ParallelLogManager:
    """Manager for multiple parallel loggers."""
    
    def __init__(self):
        self.loggers = {}
        self.execution_order = []
    
    def get_logger(self, task_id: str) -> ParallelLogger:
        """Get or create a logger for a task."""
        if task_id not in self.loggers:
            self.loggers[task_id] = ParallelLogger(task_id)
            self.execution_order.append(task_id)
        return self.loggers[task_id]
    
    def print_all_logs(self, title: str = "Parallel Execution Results"):
        """Print all logs in organized format."""
        print(f"\n{'='*80}")
        print(f"{title}")
        print(f"{'='*80}")
        
        for task_id in self.execution_order:
            logger = self.loggers[task_id]
            print(f"\n--- Task: {task_id} ---")
            logger.print_logs("  ")
        
        print(f"{'='*80}")
    
    def clear(self):
        """Clear all loggers."""
        self.loggers.clear()
        self.execution_order.clear()

print("ParallelLogger system created!")
# Out:
# ParallelLogger system created!

# %% [markdown]
# ## Environment Setup
#
# Before we start building our adaptive RAG system, let's verify that all required API keys are available. We need both OpenAI for language models and embeddings, and Tavily for web search capabilities.

# %%
# Check if OpenAI API key is available
openai_api_key = os.getenv("OPENAI_API_KEY")
if not openai_api_key:
    raise ValueError("OPENAI_API_KEY environment variable is required")

# Check if Tavily API key is available
tavily_api_key = os.getenv("TAVILY_API_KEY")
if not tavily_api_key:
    raise ValueError("TAVILY_API_KEY environment variable is required for web search functionality")

print("OpenAI API key found!")
print("Tavily API key found!")
# Out:
# OpenAI API key found!
# Tavily API key found!

# %% [markdown]
# ## Connect to ChromaDB Collections
#
# We'll use the same domain-separated ChromaDB collections from the router RAG notebook. This separation allows us to route queries to the most appropriate knowledge domains: product catalog, FAQ, and troubleshooting guides.

# %%
# Initialize embeddings model
embeddings = OpenAIEmbeddings(
    model=os.getenv("OPENAI_EMBEDDING_MODEL", "text-embedding-3-small"),
    api_key=openai_api_key
)

# Path to the separate ChromaDB collections
chroma_db_path = Path("..") / "vector_store" / "chroma_db_separate"

# Connect to each collection
catalog_store = Chroma(
    collection_name="techmart_catalog",
    embedding_function=embeddings,
    persist_directory=str(chroma_db_path)
)

faq_store = Chroma(
    collection_name="techmart_faq",
    embedding_function=embeddings,
    persist_directory=str(chroma_db_path)
)

troubleshooting_store = Chroma(
    collection_name="techmart_troubleshooting",
    embedding_function=embeddings,
    persist_directory=str(chroma_db_path)
)

# Create a mapping for easy access
collections = {
    "catalog": catalog_store,
    "faq": faq_store,
    "troubleshooting": troubleshooting_store
}

print(f"Connected to ChromaDB collections at: {chroma_db_path}")
for name, store in collections.items():
    print(f"{name}: {store._collection.count()} documents")
# Out:
# Connected to ChromaDB collections at: ../vector_store/chroma_db_separate
# catalog: 325 documents
# faq: 50 documents
# troubleshooting: 154 documents

# %% [markdown]
# ## Initialize Language Models
#
# For optimal performance, we use different specialized language models for different tasks:
# - **Analysis LLM**: Most capable model for complex query analysis and decomposition
# - **Generation LLM**: Balanced model for answer generation
# - **Evaluation LLM**: Fast model for document relevance evaluation

# %%
# Initialize separate language models for different tasks
analysis_llm = ChatOpenAI(
    model="gpt-5.4",
    api_key=openai_api_key,
)

generation_llm = ChatOpenAI(
    model="gpt-5.4-mini",
    api_key=openai_api_key,
)

evaluation_llm = ChatOpenAI(
    model="gpt-5.4-mini",
    api_key=openai_api_key,
)

print(f"Analysis language model initialized: {analysis_llm.model_name}")
print(f"Generation language model initialized: {generation_llm.model_name}")
print(f"Evaluation language model initialized: {evaluation_llm.model_name}")
# Out:
# Analysis language model initialized: gpt-5.4
# Generation language model initialized: gpt-5.4-mini
# Evaluation language model initialized: gpt-5.4-mini

# %% [markdown]
# ## Subgraph State Definition
#
# We need to define the state structure for processing individual queries through our subgraph. This state will track the journey of a single query from initial analysis through retrieval, evaluation, and generation.

# %%
# Subgraph state for individual query processing
class ProcessQueryGraphState(TypedDict):
    """State for processing a single query through the subgraph."""
    query: str
    rewritten_query: str
    reason_for_rewrite: str
    needs_rewrite: bool
    num_retries: int
    routing_decision: str
    retrieved_docs: List[Document] # 5 docs
    relevant_docs: List[Document] # 2 relevant docs
    subquery_answer: str
    logger: ParallelLogger

print("Subgraph state definition created!")
# Out:
# Subgraph state definition created!

# %% [markdown]
# ## Query Router
#
# Now we'll create a query router chain that determines collections for each individual query.

# %%
class QueryRouting(BaseModel):
    """Routing decision for a single query."""
    collection_needed: Literal["catalog", "faq", "troubleshooting", "web_search"] = Field(
        description="Collections that should be searched"
    )
    reasoning: str = Field(
        description="Explanation of the routing decision"
    )

# Query routing prompt for individual queries
routing_prompt = ChatPromptTemplate.from_template(
    """You are a query router for TechMart's RAG system.
Determine which collections should be searched for this specific query.

Available collections:
- **catalog**: Product information, specifications, recommendations
- **faq**: Customer service, shipping, returns, policies
- **troubleshooting**: Technical support, problem diagnosis, solutions for TechMart products
- **web_search**: For troubleshooting questions about issues not covered in our internal troubleshooting database, or for getting the latest information about software, drivers, or technical problems that require current information from the internet

Search strategies:
- **single_collection**: Search one most relevant collection
- **multi_collection**: Search 2-3 relevant collections
- **comprehensive**: Search all collections for complex/vague queries

Collection selection rules:
- Use **web_search** for troubleshooting issues that are likely not covered in our limited internal database
- Use **web_search** for current software, driver, or OS compatibility issues
- Use internal collections (catalog, faq, troubleshooting) for TechMart-specific information

Examples:
1. "What gaming laptops do you have?" -> Collections: ["catalog"]
2. "What are your return policies?" -> Collections: ["faq"]
3. "My laptop won't turn on" -> Collections: ["troubleshooting"]
4. "Windows 11 blue screen error 0x0000007E" -> Collections: ["web_search"]
5. "Latest NVIDIA driver causing display issues" -> Collections: ["web_search"]
6. "I need a laptop" -> Collections: ["catalog"]

Query: {query}

Determine the routing:
"""
)

# Create routing chain
routing_chain = routing_prompt | analysis_llm.with_structured_output(QueryRouting)

print("Query router created!")
# Out:
# Query router created!

# %% [markdown]
# ## Document Grading System
#
# After retrieving documents, we need to evaluate their relevance to the query. This grading system helps us filter out irrelevant documents and determine if we need to retry with a rewritten query.

# %%
class DocumentGrade(BaseModel):
    """Grade for document relevance."""
    relevant: Literal["yes", "no"] = Field(
        description="Whether the document is relevant to the query"
    )
    reasoning: str = Field(
        description="Brief explanation of the relevance assessment"
    )

# Document grading prompt
grading_prompt = ChatPromptTemplate.from_template(
    """You are evaluating the relevance of a retrieved document to a user query.

Query: {query}

Document:
{document}

Instructions:
- Mark as "yes" if the document contains information that helps answer the query, even if:
  - The SKU number differs
  - The model variant or version name (e.g., “Wireless” vs. base model) is different but from the same product family
- Mark as "no" only if the product in the document is clearly a different, unrelated product line.
- Focus on the product family and core features described, not exact SKUs or small variant descriptors.
- Give brief reasoning for your assessment.
Evaluate the document relevance.
"""
)

# Create grading chain with evaluation LLM
grading_chain = grading_prompt | evaluation_llm.with_structured_output(DocumentGrade)

import asyncio
async def evaluate_documents(query: str, documents: List[Document], logger: ParallelLogger) -> List[Document]:
    """Evaluate document relevance in parallel and return relevant docs with quality score."""
    if not documents:
        logger.log("No documents to evaluate")
        return []
    
    logger.log(f"Evaluating {len(documents)} documents for query: {query}")
    
    # Evaluate all documents in parallel
    tasks = [
        grading_chain.ainvoke({"query": query, "document": doc.page_content}) 
        for doc in documents
    ]
    grades = await asyncio.gather(*tasks)
    
    # Process results
    relevant_docs = []
    
    for doc, grade in zip(documents, grades):
        if grade.relevant == "yes":
            relevant_docs.append(doc)
            logger.log(f"✓ Relevant doc: {grade.reasoning}")
        else:
            logger.log(f"✗ Irrelevant doc: {grade.reasoning}")
    
    logger.log(f"Document evaluation complete: {len(relevant_docs)}/{len(documents)} relevant")
    
    return relevant_docs

print("Document evaluation system created!")
# Out:
# Document evaluation system created!

# %% [markdown]
# ## Query Rewriting and Expansion
#
# When initial results are poor, we can rewrite the query to improve retrieval.

# %%
class QueryRewrite(BaseModel):
    """Rewritten query for better retrieval."""
    rewritten_query: str = Field(
        description="Improved version of the original query"
    )
    improvements: str = Field(
        description="Explanation of what was improved"
    )

# Query rewriting prompt - enhanced to handle context
rewrite_prompt = ChatPromptTemplate.from_template(
    """You are helping improve a query for better document retrieval.
The original query may need enhancement either for general improvement or by incorporating previous context.

Original query: {query}
Previous context: {previous_context}

Context: This is for a TechMart electronics store with products, customer service info, and troubleshooting guides.

Rewriting strategies:
- If previous_context is provided, incorporate specific findings (product names, models, details) into the query
- Add more specific terms and context from previous results
- Expand abbreviations and clarify ambiguous terms  
- Add relevant synonyms or alternative phrasings
- Make implicit requirements explicit

Examples with context:
- Original: "Check if has issues" + Context: "Found GlideMaster MX Wireless Mouse as best mouse" 
  → "Check if GlideMaster MX Wireless Mouse has known issues, problems, or user complaints"
- Original: "What about warranty" + Context: "User interested in ZenithBook 13 Evo laptop"
  → "What is the warranty coverage and terms for ZenithBook 13 Evo laptop"

Examples without context:
- "fast computer" → "high performance laptop with fast processor and SSD storage"
- "setup help" → "step by step guide for setting up and configuring new computer"
- "won't work" → "troubleshooting device not functioning properly or not turning on"

Provide an improved query:
"""
)

# Create rewriting chain with analysis LLM
rewrite_chain = rewrite_prompt | analysis_llm.with_structured_output(QueryRewrite)

print("Enhanced query rewriting system created using gpt-5.4-mini!")
# Out:
# Enhanced query rewriting system created using gpt-5.4-mini!

# %% [markdown]
# ## Answer Generation for Subqueries
#
# Each subquery processed through our subgraph needs to generate a focused answer based on the relevant documents found. This answer will later be combined with other subquery results to form the final response.

# %%
# Subquery answer generation

subquery_answer_generation_prompt = ChatPromptTemplate.from_template(
    """You are a helpful assistant for TechMart, an electronics retailer.
    Use the following relevant documents to answer the specific query.

    Query: {query}
    
    Context from relevant documents:
    {context}

    Instructions:
    - Provide a focused answer to this specific query
    - Be concise but informative
    - Include specific product details when available
    - If no relevant documents were found, acknowledge the limitation

    Answer:
    """
)

subquery_answer_generation_chain = subquery_answer_generation_prompt | generation_llm

print("Subquery answer generation chain created!")
# Out:
# Subquery answer generation chain created!

# %% [markdown]
# ## Define Subgraph Nodes and Conditional Logic
#
# Now we'll define the individual nodes that make up our subgraph workflow. Each node handles a specific step in processing a single query:
#
# - **Query Rewriter**: Enhances queries with context (first node in the pipeline)
# - **Router**: Determines which collection to search based on query content
# - **Retrieval Nodes**: Search specific collections (catalog, FAQ, troubleshooting, web)
# - **Evaluation**: Grades document relevance and determines if retry is needed
# - **Answer Generation**: Creates focused responses from relevant documents
#
# The conditional logic determines the flow between nodes, including retry mechanisms when initial retrieval fails to find relevant documents.

# %%
# define the conditional edges that determine the next node to visit
def should_retry_with_rewrite(state: ProcessQueryGraphState) -> str:
    """Determine if query should be retried with rewriting or proceed to generation."""
    needs_rewrite = state.get("needs_rewrite", False)
    num_retries = state.get("num_retries", 0)
    logger = state["logger"]
    
    # Proceed to rewrite if flag is set and we haven't exceeded retry limit
    if needs_rewrite and num_retries < 2:
        logger.log(f"Will retry with query rewriting (attempt {num_retries}, needs_rewrite={needs_rewrite})")
        return "query_rewriter_node"
    else:
        # Either we don't need rewrite or already retried maximum times
        if needs_rewrite and num_retries >= 2:
            logger.log(f"Max retries reached ({num_retries}), proceeding to generation despite needing rewrite")
        else:
            logger.log(f"No rewrite needed or found relevant documents, proceeding to generation")
        return "generate_subquery_answer"

# define the nodes
def query_rewriter_node(state: ProcessQueryGraphState) -> ProcessQueryGraphState:
    """Rewrite query with context if needed, otherwise pass through."""
    query = state["query"]
    needs_rewrite = state.get("needs_rewrite", False)
    reason_for_rewrite = state.get("reason_for_rewrite", "")
    num_retries = state.get("num_retries", 0)
    logger = state["logger"]
    
    # Check if this is a retry due to no relevant docs
    if num_retries > 0:
        logger.log(f"Retrying query rewrite due to no relevant documents: {query}")
        reason_for_rewrite = "No relevant documents found, improving query for better retrieval"
        needs_rewrite = True
    
    if not needs_rewrite:
        # Skip rewriting, pass through original query
        logger.log(f"Skipping query rewrite for: {query}")
        return {
            "rewritten_query": query, 
            "needs_rewrite": False,
            "num_retries": num_retries
        }
    
    # Rewrite query using previous context
    logger.log(f"Rewriting query with context: {query}")
    logger.log(f"Previous context: {reason_for_rewrite}")
    
    rewrite_result = rewrite_chain.invoke({
        "query": query,
        "previous_context": reason_for_rewrite
    })
    
    logger.log(f"Original query: {query}")
    logger.log(f"Rewritten query: {rewrite_result.rewritten_query}")
    logger.log(f"Improvements: {rewrite_result.improvements}")
    
    return {
        "rewritten_query": rewrite_result.rewritten_query,
        "reason_for_rewrite": f"Enhanced: {rewrite_result.improvements}",
        "needs_rewrite": False,  # Always reset flag after rewriting
        "num_retries": num_retries  # Don't modify counter here
    }

def route_query(state: ProcessQueryGraphState) -> ProcessQueryGraphState:
    """Route individual query to appropriate collections."""
    # Use rewritten_query instead of query
    query = state["rewritten_query"]
    logger = state["logger"]
    
    # Route the query
    routing = routing_chain.invoke({"query": query})
    
    logger.log(f"Routing query: {query}")
    logger.log(f"Reasoning: {routing.reasoning}")
    
    return {
        "routing_decision": routing.collection_needed if routing.collection_needed else "catalog"
    }

def retrieve_from_catalog(state: ProcessQueryGraphState) -> ProcessQueryGraphState:
    """Retrieve documents from the product catalog."""
    query = state["rewritten_query"]  # Use rewritten_query
    logger = state["logger"]
    retrieved_docs = catalog_store.similarity_search(query, k=5)
    
    logger.log(f"Retrieved {len(retrieved_docs)} documents from catalog")
    for i, doc in enumerate(retrieved_docs, 1):
        source = doc.metadata.get('source', 'Unknown')
        content_preview = doc.page_content[:100]
        logger.log(f"  Doc {i} [{source}]: {content_preview}...")
    
    return {"retrieved_docs": retrieved_docs}

def retrieve_from_faq(state: ProcessQueryGraphState) -> ProcessQueryGraphState:
    """Retrieve documents from the FAQ collection."""
    query = state["rewritten_query"]  # Use rewritten_query
    logger = state["logger"]
    retrieved_docs = faq_store.similarity_search(query, k=5)
    
    logger.log(f"Retrieved {len(retrieved_docs)} documents from FAQ")
    for i, doc in enumerate(retrieved_docs, 1):
        source = doc.metadata.get('source', 'Unknown')
        content_preview = doc.page_content[:100]
        logger.log(f"  Doc {i} [{source}]: {content_preview}...")
    
    return {"retrieved_docs": retrieved_docs}

def retrieve_from_troubleshooting(state: ProcessQueryGraphState) -> ProcessQueryGraphState:
    """Retrieve documents from the troubleshooting collection."""
    query = state["rewritten_query"]  # Use rewritten_query
    logger = state["logger"]
    retrieved_docs = troubleshooting_store.similarity_search(query, k=5)
    
    logger.log(f"Retrieved {len(retrieved_docs)} documents from troubleshooting")
    for i, doc in enumerate(retrieved_docs, 1):
        source = doc.metadata.get('source', 'Unknown')
        content_preview = doc.page_content[:100]
        logger.log(f"  Doc {i} [{source}]: {content_preview}...")
    
    return {"retrieved_docs": retrieved_docs}

# Initialize Tavily search for web search
tavily_search = TavilySearch(
    max_results=5,  # Number of search results to return
    tavily_api_key=tavily_api_key,
)

def retrieve_from_web_search(state: ProcessQueryGraphState) -> ProcessQueryGraphState:
    """Retrieve documents from web search using Tavily."""
    query = state["rewritten_query"]  # Use rewritten_query
    logger = state["logger"]
    
    # Use Tavily to search the web, then convert the results into Document objects
    search_response = tavily_search.invoke({"query": query})
    retrieved_docs = [
        Document(
            page_content=result["content"],
            metadata={"source": result["url"], "title": result.get("title", "")},
        )
        for result in search_response.get("results", [])
    ]
    
    logger.log(f"Retrieved {len(retrieved_docs)} documents from web search")
    for i, doc in enumerate(retrieved_docs, 1):
        source = doc.metadata.get('source', 'Unknown')
        content_preview = doc.page_content[:100]
        logger.log(f"  Doc {i} [{source}]: {content_preview}...")
    
    return {"retrieved_docs": retrieved_docs}

async def evaluate_retrieved_documents(state: ProcessQueryGraphState) -> ProcessQueryGraphState:
    """Evaluate the quality of retrieved documents for a single query."""
    # Use rewritten_query for evaluation
    query = state["rewritten_query"]
    docs = state["retrieved_docs"]
    num_retries = state.get("num_retries", 0)
    logger = state["logger"]
    
    logger.log(f"Evaluating {len(docs)} documents for query: {query}")
    
    # Evaluate document relevance
    relevant_docs = await evaluate_documents(query, docs, logger)
    
    logger.log(f"Query Quality Assessment:")
    logger.log(f"Relevant docs: {len(relevant_docs)}/{len(docs)}")
    
    # Handle retry logic based on results
    if len(relevant_docs) == 0:
        # No relevant docs found - signal for retry and increment counter
        new_retries = num_retries + 1
        logger.log(f"No relevant docs found, setting needs_rewrite=True and incrementing retries: {num_retries} → {new_retries}")
        return {
            "relevant_docs": relevant_docs,
            "needs_rewrite": True,
            "num_retries": new_retries
        }
    else:
        # Found relevant docs - no retry needed
        logger.log(f"Found {len(relevant_docs)} relevant docs, no retry needed")
        return {
            "relevant_docs": relevant_docs,
            "needs_rewrite": False,
            "num_retries": num_retries  # Keep current value
        }

def generate_subquery_answer(state: ProcessQueryGraphState) -> ProcessQueryGraphState:
    """Generate answer for the subquery using relevant documents."""
    # Use rewritten_query for generation
    query = state["rewritten_query"]
    relevant_docs = state["relevant_docs"]
    logger = state["logger"]
    
    logger.log(f"Generating answer for subquery: {query}")
    
    # Prepare context from relevant documents
    if relevant_docs:
        context_parts = []
        for doc in relevant_docs:
            collection = doc.metadata.get('collection', 'unknown')
            source = doc.metadata.get('source', 'unknown')
            context_parts.append(f"[{collection.upper()}] {source}: {doc.page_content}")
        context_text = "\n\n".join(context_parts)
    else:
        context_text = "No relevant documents found for this subquery."
    
    # Generate response using the subquery generation chain
    response = subquery_answer_generation_chain.invoke({
        "query": query,
        "context": context_text
    })
    
    logger.log(f"Generated subquery answer: {response.content}")
    
    return {
        "subquery_answer": response.content
    }
    
def rewrite_query(state: ProcessQueryGraphState) -> ProcessQueryGraphState:
    """Rewrite query for better retrieval."""
    original_query = state["original_query"]
    retry_count = state["retry_count"]
    logger = state["logger"]
    
    logger.log(f"Rewriting query (attempt {retry_count + 1})...")
    
    # Rewrite the query
    rewrite = rewrite_chain.invoke({"query": original_query})
    
    logger.log(f"Original: {original_query}")
    logger.log(f"Rewritten: {rewrite.rewritten_query}")
    logger.log(f"Improvements: {rewrite.improvements}")
    
    return {
        "query": rewrite.rewritten_query,
        "rewritten_query": rewrite.rewritten_query,
        "needs_rewrite": False,
        "retry_count": retry_count + 1
    }

print("Subgraph nodes with fixed retry logic created!")
# Out:
# Subgraph nodes with fixed retry logic created!

# %% [markdown]
# ## Building the Subgraph
#
# The subgraph handles the complete lifecycle of processing a single query, starting with query rewriting/enhancement, then routing → retrieval → evaluation → generation. It includes self-correction mechanisms to retry with rewritten queries when initial retrieval fails.

# %%
# Define routing function for conditional edges  
def route_to_retrieval_source(state: ProcessQueryGraphState) -> str:
    """Determine which retrieve node to call based on router decision."""
    routing_decision = state["routing_decision"]
    return f"retrieve_from_{routing_decision}"

# Build the subgraph
subgraph_builder = StateGraph(ProcessQueryGraphState)

# Add query rewriter node as new entry point
subgraph_builder.add_node("query_rewriter_node", query_rewriter_node)

# Add routing node
subgraph_builder.add_node("route_query", route_query)

# Add separate retrieval nodes
subgraph_builder.add_node("retrieve_from_catalog", retrieve_from_catalog)
subgraph_builder.add_node("retrieve_from_faq", retrieve_from_faq)
subgraph_builder.add_node("retrieve_from_troubleshooting", retrieve_from_troubleshooting)
subgraph_builder.add_node("retrieve_from_web_search", retrieve_from_web_search)

# Add evaluation node
subgraph_builder.add_node("evaluate_retrieved_documents", evaluate_retrieved_documents)

# Add generation node
subgraph_builder.add_node("generate_subquery_answer", generate_subquery_answer)

# Set entry point for subgraph to query rewriter
subgraph_builder.add_edge(START, "query_rewriter_node")

# Add edge from query rewriter to router
subgraph_builder.add_edge("query_rewriter_node", "route_query")

# Add conditional edges from router to appropriate retrieve node
subgraph_builder.add_conditional_edges(
    "route_query",
    route_to_retrieval_source,
    {
        "retrieve_from_catalog": "retrieve_from_catalog",
        "retrieve_from_faq": "retrieve_from_faq", 
        "retrieve_from_troubleshooting": "retrieve_from_troubleshooting",
        "retrieve_from_web_search": "retrieve_from_web_search"
    }
)

# All retrieve nodes go to evaluation
subgraph_builder.add_edge("retrieve_from_catalog", "evaluate_retrieved_documents")
subgraph_builder.add_edge("retrieve_from_faq", "evaluate_retrieved_documents")
subgraph_builder.add_edge("retrieve_from_troubleshooting", "evaluate_retrieved_documents")
subgraph_builder.add_edge("retrieve_from_web_search", "evaluate_retrieved_documents")

# Add conditional edges from evaluation - either retry or proceed to generation
subgraph_builder.add_conditional_edges(
    "evaluate_retrieved_documents",
    should_retry_with_rewrite,
    {
        "query_rewriter_node": "query_rewriter_node",
        "generate_subquery_answer": "generate_subquery_answer"
    }
)

# Generation is the end
subgraph_builder.add_edge("generate_subquery_answer", END)

# Compile the subgraph
process_query_subgraph = subgraph_builder.compile()

print("Query processing subgraph with self-correction mechanism created and compiled!")
# Out:
# Query processing subgraph with self-correction mechanism created and compiled!

# %%
# visualize the subgraph
from IPython.display import Image, display
# s1 -> s2 -> s3 
display(Image(process_query_subgraph.get_graph().draw_mermaid_png()))

# %% [markdown]
# ## Query Analysis and Decomposition
#
# The first step in our adaptive RAG system is analyzing the query to determine the optimal processing strategy. This analysis focuses specifically on **query decomposition** - deciding whether a complex query should be broken down into simpler sub-queries.
#
# ### Key Analysis Components:
#
# 1. **Decomposition Detection**: Identifies queries that contain multiple distinct questions or span unrelated domains
# 2. **Execution Planning**: Determines whether sub-queries should run in parallel (independent) or sequentially (dependent)
# 3. **Dependency Analysis**: Recognizes when later queries need results from earlier ones
#
# ### Examples of Decomposition:
# - **Parallel**: "What laptops do you have AND what are your return policies?" → Two independent questions
# - **Sequential**: "Find the best gaming mouse, THEN check if it has issues" → Second query depends on first result
# - **No Decomposition**: "What are the specs of UltraBook Pro 14?" → Single cohesive question
#
# This analysis enables our system to handle complex, multi-part queries more effectively than simple routing approaches.

# %%
class QueryAnalysis(BaseModel):
    """Analysis of query characteristics - focused on decomposition only."""
    needs_decomposition: bool = Field(
        description="Whether the query should be broken down into sub-queries"
    )
    sub_queries: List[str] = Field(
        description="List of sub-queries if decomposition is needed",
        default_factory=list
    )
    execution_plan: Literal["sequential", "parallel"] = Field(
        description="How sub-queries should be executed",
        default="parallel"
    )
    reasoning: str = Field(
        description="Explanation of the decomposition analysis"
    )

# Query analysis prompt - focused only on decomposition, not collection routing
query_analysis_prompt = ChatPromptTemplate.from_template(
    """You are a query decomposition analyzer for TechMart's adaptive RAG system.
Your job is to determine if a query needs decomposition.

Query decomposition rules:
- **Decompose if**: Query contains multiple distinct questions, has complex AND/OR logic, or spans multiple unrelated domains, or asks about multiple products
- **Don't decompose if**: Query is cohesive even if complex, or sub-parts heavily depend on each other

Execution plans:
- **sequential**: When later sub-queries depend on earlier results (e.g., "Find gaming laptops, then tell me about warranty for the best one")
- **parallel**: When sub-queries are independent (e.g., "What gaming laptops do you have and what are your shipping options?")

Examples:
1. "What gaming laptops do you have and what are your return policies?" 
   - Decompose: Yes, Sub-queries: ["What gaming laptops do you have?", "What are your return policies?"], Execution: parallel

2. "I need a laptop under $1000, then tell me how long shipping takes for my choice"
   - Decompose: Yes, Sub-queries: ["Show me laptops under $1000", "How long does shipping take?"], Execution: sequential

3. "What are the specs of the UltraBook Pro 14?"
   - Decompose: No

4. "Windows 11 blue screen error 0x0000007E - how do I fix this?"
   - Decompose: No

5. "My laptop won't turn on"
   - Decompose: No

6. "I need a laptop and want to know about Chrome crashes on macOS"
   - Decompose: Yes, Sub-queries: ["I need a laptop", "How to fix Chrome crashes on macOS"], Execution: parallel

Query: {query}

Provide your query analysis:
"""
)

# Create decomposition analysis chain with analysis LLM
query_analysis_chain = query_analysis_prompt | analysis_llm.with_structured_output(QueryAnalysis)

print("Query analysis system created using gpt-5.4-mini!")
# Out:
# Query analysis system created using gpt-5.4-mini!

# %% [markdown]
# ## Test Query Analysis
#
# Let's test our query analyzer with different types of queries.

# %%
# Test queries of varying complexity including decomposition examples
test_queries = [
    "What are the specs of the UltraBook Pro 14?",  # no decomposition
    "What gaming laptops do you have and what are your return policies?",  # parallel decomposition
    "battery life for zenithbook air 15 vs ultrabook 14 pro",  # parallel decomposition
    "I need a laptop and want to know about Chrome crashes on macOS",  # parallel decomposition
]

print("Testing Query Decomposition Analysis:")
print("=" * 90)

for query in test_queries:
    analysis = query_analysis_chain.invoke({"query": query})
    print(f"\nQuery: {query}")
    print(f"Needs Decomposition: {analysis.needs_decomposition}")
    if analysis.needs_decomposition:
        print(f"Sub-queries: {analysis.sub_queries}")
        print(f"Execution Plan: {analysis.execution_plan}")
    print(f"Reasoning: {analysis.reasoning}")
    print("-" * 80)
# Out:
# Testing Query Decomposition Analysis:
# ==========================================================================================
#
# Query: What are the specs of the UltraBook Pro 14?
# Needs Decomposition: False
# Reasoning: This query asks a single cohesive question about one specific product: the specs of the UltraBook Pro 14. It does not contain multiple distinct questions, complex logic, unrelated domains, or multiple products.
# --------------------------------------------------------------------------------
#
# Query: What gaming laptops do you have and what are your return policies?
# Needs Decomposition: True
# Sub-queries: ['What gaming laptops do you have?', 'What are your return policies?']
# Execution Plan: parallel
# Reasoning: The query contains two distinct, independent questions: one about product availability and another about store policies. These can be answered separately without depending on each other, so decomposition is appropriate and the sub-queries can be executed in parallel.
# --------------------------------------------------------------------------------
#
# Query: battery life for zenithbook air 15 vs ultrabook 14 pro
# Needs Decomposition: True
# Sub-queries: ['What is the battery life of the ZenithBook Air 15?', 'What is the battery life of the UltraBook 14 Pro?']
# Execution Plan: parallel
# Reasoning: The query compares two distinct products, which matches the rule to decompose when asking about multiple products. Each sub-query is independent and can be answered separately, then combined for comparison.
# --------------------------------------------------------------------------------
#
# Query: I need a laptop and want to know about Chrome crashes on macOS
# Needs Decomposition: True
# Sub-queries: ['I need a laptop', 'How to fix Chrome crashes on macOS']
# Execution Plan: parallel
# Reasoning: The query spans two unrelated domains: product discovery for a laptop and technical troubleshooting for Chrome crashes on macOS. These are distinct questions that can be handled independently, so decomposition is needed and the sub-queries can be executed in parallel.
# --------------------------------------------------------------------------------
# Query: What are the specs of the UltraBook Pro 14?
# Needs Decomposition: False
# Reasoning: The query asks a single, cohesive question about one product’s specifications. There are no multiple distinct questions, no branching logic, and no need to split into sub-queries.
# --------------------------------------------------------------------------------
# Query: What gaming laptops do you have and what are your return policies?
# Needs Decomposition: True
# Sub-queries: ['What gaming laptops do you have?', 'What are your return policies?']
# Execution Plan: parallel
# Reasoning: The query contains two distinct, independent questions spanning separate product/catalog and policy domains. Each can be answered without the other, so it should be decomposed and executed in parallel.
# --------------------------------------------------------------------------------
# Query: battery life for zenithbook air 15 vs ultrabook 14 pro
# Needs Decomposition: True
# Sub-queries: ['What is the battery life of ZenithBook Air 15?', 'What is the battery life of UltraBook 14 Pro?']
# Execution Plan: parallel
# Reasoning: The query compares battery life across two distinct products. Each product’s battery-life information can be retrieved independently, so the query should be decomposed into two parallel sub-queries.
# --------------------------------------------------------------------------------
# Query: I need a laptop and want to know about Chrome crashes on macOS
# Needs Decomposition: True
# Sub-queries: ['I need a laptop', 'How to fix Chrome crashes on macOS']
# Execution Plan: parallel
# Reasoning: The query contains two distinct and unrelated requests: one for a laptop product and another for troubleshooting Chrome crashes on macOS. These span different domains and can be handled independently, so decomposition is needed with a parallel execution plan.
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Define Main Graph State
#
# The main graph coordinates the overall adaptive RAG process. It analyzes queries for decomposition, processes subqueries (either sequentially or in parallel), and combines results into a final answer.

# %%
class MainGraphState(TypedDict):
    """State for our 3-node Adaptive RAG workflow."""
    # Input
    query: str
    original_query: str
    
    # Query decomposition results
    needs_decomposition: bool
    sub_queries: List[str]
    execution_plan: str  # "sequential" or "parallel"
    
    # Results storage: query -> list of documents
    query_results: dict  # Dict[str, List[Document]]
    
    # Final results
    all_retrieved_docs: List[Document]
    
    # Output
    answer: str
    
print("Main graph state created!")
# Out:
# Main graph state created!

# %%
# Global log manager for parallel execution
log_manager = ParallelLogManager()

# define a helper function to process a single query using the subgraph
async def _process_single_query(query: str, needs_rewrite: bool = False, previous_context: str = "") -> Dict:
    """Process a single query through the subgraph."""
    # Create logger for this specific query
    logger = log_manager.get_logger(query)
    logger.log(f"Starting processing for query: {query}")
    
    # Initialize subgraph state with logger and all required fields
    subgraph_state = {
        "query": query,
        "rewritten_query": "",  # Will be set by query_rewriter_node
        "reason_for_rewrite": previous_context,
        "needs_rewrite": needs_rewrite,
        "num_retries": 0,  # Initialize retry counter
        "routing_decision": "",
        "retrieved_docs": [],
        "relevant_docs": [],
        "subquery_answer": "",
        "logger": logger
    }
    
    # Run the subgraph
    result = await process_query_subgraph.ainvoke(subgraph_state)
    
    logger.log(f"Completed processing for query: {query}")
    
    return {
        "query": query,
        "documents": result.get("relevant_docs", []),
        "subquery_answer": result.get("subquery_answer", "")
    }

# %% [markdown]
# ## Main Graph Nodes
#
# The main graph consists of three primary nodes that orchestrate the entire adaptive RAG workflow: query analysis, query processing, and final answer generation.

# %%
import asyncio

# 3-node main graph

def query_analysis(state: MainGraphState) -> MainGraphState:
    """Decompose query and determine execution plan."""
    query = state["query"]
    
    # Clear previous logs
    log_manager.clear()
    
    # Analyze the query for decomposition only
    analysis = query_analysis_chain.invoke({"query": query})
    
    print(f"Query Decomposition Analysis:")
    print(f"  Needs Decomposition: {analysis.needs_decomposition}")
    if analysis.needs_decomposition:
        print(f"  Sub-queries: {analysis.sub_queries}")
        print(f"  Execution Plan: {analysis.execution_plan}")
    print(f"  Reasoning: {analysis.reasoning}")
    
    return {
        "original_query": query,
        "needs_decomposition": analysis.needs_decomposition,
        "sub_queries": analysis.sub_queries if analysis.needs_decomposition else [query],
        "execution_plan": analysis.execution_plan,
        "query_results": {}
    }

async def process_queries(state: MainGraphState) -> MainGraphState:
    """Process queries using asyncio for sequential/parallel execution with organized logging."""
    sub_queries = state["sub_queries"]
    execution_plan = state["execution_plan"]
    needs_decomposition = state["needs_decomposition"]
    
    query_results = {}
    all_docs = []
    
    if not needs_decomposition:
        # Single query - no rewriting needed
        print(f"\nProcessing single query: {sub_queries[0]}")
        result = await _process_single_query(sub_queries[0], needs_rewrite=False)
        query_results[result["query"]] = result["documents"]
        all_docs.extend(result["documents"])
        
        # Print organized logs for single query
        log_manager.print_all_logs("Single Query Processing")
        
    elif execution_plan == "parallel":
        # Parallel execution - no rewriting needed for any query
        print(f"\nExecuting {len(sub_queries)} queries in parallel")
        
        # Create tasks for all queries (no context needed for parallel)
        tasks = [_process_single_query(query, needs_rewrite=False) for query in sub_queries]
        
        # Wait for all tasks to complete
        results = await asyncio.gather(*tasks)
        
        # Process results
        for result in results:
            query_results[result["query"]] = result["documents"]
            all_docs.extend(result["documents"])
        
        # Print organized logs for parallel execution
        log_manager.print_all_logs("Parallel Query Processing")
                
    else:  # sequential
        # Sequential execution with context accumulation
        print(f"\nExecuting {len(sub_queries)} queries sequentially")
        
        accumulated_context = ""
        for i, query in enumerate(sub_queries, 1):
            print(f"\n--- Sequential Step {i}/{len(sub_queries)} ---")
            
            # First query doesn't need rewriting, subsequent ones do
            needs_rewrite = i > 1
            
            result = await _process_single_query(
                query, 
                needs_rewrite=needs_rewrite, 
                previous_context=accumulated_context
            )
            
            query_results[result["query"]] = result["documents"]
            all_docs.extend(result["documents"])
            
            # Accumulate context for next query
            accumulated_context += f"Step {i} result: {result['subquery_answer']}\n"
            
            # Print logs for this step immediately
            if query in log_manager.loggers:
                print(f"\nStep {i} Processing Details:")
                log_manager.loggers[query].print_logs("  ")
    
    print(f"\n{'='*80}")
    print(f"Query Processing Summary:")
    print(f"  Total queries processed: {len(sub_queries)}")
    print(f"  Total documents retrieved: {len(all_docs)}")
    print(f"  Execution strategy: {execution_plan}")
    print(f"{'='*80}")
    
    return {
        "query_results": query_results,
        "all_retrieved_docs": all_docs,
    }

# %%
# Generation prompt for main graph
final_generate_prompt = ChatPromptTemplate.from_template(
    """You are a helpful assistant for TechMart, an electronics retailer.
Use the following context to answer the user's question accurately and helpfully.

Original Question: {original_question}
Query was decomposed: {was_decomposed}
{decomposition_info}

Total Relevant Documents: {num_docs}

Context:
{context}

Instructions:
- Provide a comprehensive answer based on the retrieved information
- If the query was decomposed, address each part of the original question
- If information spans multiple domains, organize your response clearly
- Be specific and helpful, mentioning product names and details when available
- If no relevant documents were found, provide a helpful response indicating limitations

Answer:
"""
)

def generate(state: MainGraphState) -> MainGraphState:
    """Generate final answer using combined results from all queries."""
    original_query = state["original_query"]
    needs_decomposition = state["needs_decomposition"]
    query_results = state["query_results"]
    all_docs = state["all_retrieved_docs"]
    
    print(f"Generating final answer with {len(all_docs)} total documents")
    
    # Prepare context from all documents
    if all_docs:
        context_parts = []
        for doc in all_docs:
            collection = doc.metadata.get('collection', 'unknown')
            source = doc.metadata.get('source', 'unknown')
            context_parts.append(f"[{collection.upper()}] {source}: {doc.page_content}")
        context_text = "\n\n".join(context_parts)
    else:
        context_text = "No relevant documents found."
    
    # Prepare decomposition info
    if needs_decomposition and query_results:
        decomposition_info = f"Sub-queries processed:\n"
        for query, docs in query_results.items():
            decomposition_info += f"  • {query} ({len(docs)} documents)\n"
        was_decomposed = "Yes"
    else:
        decomposition_info = ""
        was_decomposed = "No"
    
    # Generate response
    messages = final_generate_prompt.invoke({
        "context": context_text,
        "original_question": original_query,
        "was_decomposed": was_decomposed,
        "decomposition_info": decomposition_info,
        "num_docs": len(all_docs)
    })
    
    response = generation_llm.invoke(messages)
    
    print(f"Generated final answer")
    
    return {
        "answer": response.content
    }

print("Main graph nodes created!")
# Out:
# Main graph nodes created!

# %% [markdown]
# ## Build the Main Graph
#
# Now we'll create the main graph that uses subgraphs and the Send API for improved query processing.

# %%
# Create the 3-node main graph

# Build the main graph
graph_builder = StateGraph(MainGraphState)

# Add the 3 main nodes
graph_builder.add_node("query_analysis", query_analysis)
graph_builder.add_node("process_queries", process_queries)
graph_builder.add_node("generate", generate)

# Set entry point
graph_builder.add_edge(START, "query_analysis")

# Linear flow: analysis -> process -> generate
graph_builder.add_edge("query_analysis", "process_queries")
graph_builder.add_edge("process_queries", "generate")
graph_builder.add_edge("generate", END)

# Compile the graph
main_graph = graph_builder.compile()

print("3-node Adaptive RAG graph compiled successfully!")
# Out:
# 3-node Adaptive RAG graph compiled successfully!

# %% [markdown]
# ## Visualize the Main Graph
# Let's visualize our clean 3-node architecture.

# %%
from IPython.display import Image, display

print("Main Graph (3-node architecture):")
display(Image(main_graph.get_graph().draw_mermaid_png()))
# Out:
# Main Graph (3-node architecture):

# %%
async def ask_adaptive_rag(query: str):
    """Ask a question to our Adaptive RAG system with organized logging."""
    print(f"\n{'='*100}")
    print(f"ADAPTIVE RAG QUERY: {query}")
    print(f"{'='*100}")
    
    # Run the adaptive RAG workflow
    result = await main_graph.ainvoke({"query": query})
    
    print(f"\n{'='*100}")
    print(f"FINAL ANSWER:")
    print(f"{'='*100}")
    print(f"{result['answer']}")
    print(f"{'='*100}")
    print("Query processing completed successfully!")
    print(f"{'='*100}")

# %% [markdown]
# ## Testing the Adaptive RAG System
#
# Let's test our adaptive RAG system with various query types to demonstrate its capabilities: parallel decomposition, sequential processing, web search integration, and product comparisons.

# %%
# Test with parallel decomposition query
await ask_adaptive_rag("What laptops do you have with Intel i7 processors and what are your return policies?")
# Out:
# ====================================================================================================
# ADAPTIVE RAG QUERY: What laptops do you have with Intel i7 processors and what are your return policies?
# ====================================================================================================
# Query Decomposition Analysis:
#   Needs Decomposition: True
#   Sub-queries: ['What laptops do you have with Intel i7 processors?', 'What are your return policies?']
#   Execution Plan: parallel
#   Reasoning: The query contains two distinct and independent questions: one about product availability/specifications (laptops with Intel i7 processors) and one about store policies (return policies). These belong to different domains and can be answered separately without relying on each other, so decomposition is appropriate and the sub-queries can be executed in parallel.
#
# Executing 2 queries in parallel
#
# ================================================================================
# Parallel Query Processing
# ================================================================================
#
# --- Task: What laptops do you have with Intel i7 processors? ---
#   [0.00s] Starting processing for query: What laptops do you have with Intel i7 processors?
#   [0.00s] Skipping query rewrite for: What laptops do you have with Intel i7 processors?
#   [1.39s] Routing query: What laptops do you have with Intel i7 processors?
#   [1.39s] Reasoning: The query is asking for available products and specifications (laptops with Intel i7 processors), which is a product catalog search. No policy, troubleshooting, or current web information is needed.
#   [2.98s] Retrieved 5 documents from catalog
#   [2.98s]   Doc 1 [techmart_catalog.csv]: product_id: SKU232 | name: ZenithBook 11 Evo | category: Laptop | price: 1299.0 | short_desc: A slee...
#   [2.98s]   Doc 2 [techmart_catalog.csv]: product_id: SKU177 | name: ZenithBook 12 Evo | category: Laptop | price: 1299.0 | short_desc: 15.6" ...
#   [2.98s]   Doc 3 [techmart_catalog.csv]: product_id: SKU057 | name: ZenithBook 13 Evo | category: Laptop | price: 1299.0 | short_desc: Sleek ...
#   [2.98s]   Doc 4 [techmart_catalog.csv]: product_id: SKU254 | name: AeroLite 15 Slim Laptop | category: Laptop | price: 1249.0 | short_desc: ...
#   [2.98s]   Doc 5 [techmart_catalog.csv]: product_id: SKU028 | name: ZenLite 15 Evo Laptop | category: Laptop | price: 1199.0 | short_desc: Sl...
#   [3.08s] Evaluating 5 documents for query: What laptops do you have with Intel i7 processors?
#   [3.08s] Evaluating 5 documents for query: What laptops do you have with Intel i7 processors?
#   [4.52s] ✓ Relevant doc: The document is a laptop product listing and explicitly states it has an Intel Core i7 processor, which directly answers the query about laptops with Intel i7 processors.
#   [4.52s] ✓ Relevant doc: The document is for a laptop and explicitly states it is powered by an Intel Core i7 processor, which directly answers the query about laptops with Intel i7 processors.
#   [4.52s] ✓ Relevant doc: The document describes a laptop product and explicitly lists an Intel Core i7 processor, which directly matches the query about laptops with Intel i7 processors.
#   [4.52s] ✓ Relevant doc: The document describes a laptop product with an Intel Core i7 processor, which directly answers the query about laptops with Intel i7 processors.
#   [4.52s] ✗ Irrelevant doc: The document is for a laptop with an Intel Core i5 processor, not Intel i7. It does not help answer a query specifically asking for laptops with Intel i7 processors.
#   [4.52s] Document evaluation complete: 4/5 relevant
#   [4.52s] Query Quality Assessment:
#   [4.52s] Relevant docs: 4/5
#   [4.52s] Found 4 relevant docs, no retry needed
#   [4.52s] No rewrite needed or found relevant documents, proceeding to generation
#   [4.52s] Generating answer for subquery: What laptops do you have with Intel i7 processors?
#   [6.71s] Generated subquery answer: We have these laptops with Intel Core i7 processors:
#
# - **ZenithBook 11 Evo** — **$1,299**
#   Intel Core i7-1360P, 16GB RAM, 512GB storage, 11" QHD+ display, 13-hour battery, 1.35 kg
#
# - **ZenithBook 12 Evo** — **$1,299**
#   Intel Core i7-1360P, 16GB RAM, 512GB storage, 12.6" IPS display, 12-hour battery, 1.42 kg
#
# - **ZenithBook 13 Evo** — **$1,299**
#   Intel Core i7-1360P, 16GB RAM, 512GB storage, 13.6" FHD+ display, 13-hour battery, 1.45 kg
#
# - **AeroLite 15 Slim Laptop** — **$1,249**
#   Intel Core i7-1360P, 16GB RAM, 512GB storage, 15.6" FHD IPS display, 13-hour battery, 1.29 kg
#
# If you want, I can also compare them by screen size, weight, or price.
#   [6.71s] Completed processing for query: What laptops do you have with Intel i7 processors?
#
# --- Task: What are your return policies? ---
#   [0.00s] Starting processing for query: What are your return policies?
#   [0.00s] Skipping query rewrite for: What are your return policies?
#   [1.59s] Routing query: What are your return policies?
#   [1.59s] Reasoning: The query asks about return policies, which is a customer service/policy question. This belongs in the FAQ collection.
#   [2.98s] Retrieved 5 documents from FAQ
#   [2.98s]   Doc 1 [techmart_faq.csv]: question: What is your return window? | answer: Most products can be returned in like‑new condition ...
#   [2.98s]   Doc 2 [techmart_faq.csv]: question: Is return shipping free? | answer: Return shipping is free for defective items; for change...
#   [2.98s]   Doc 3 [techmart_faq.csv]: question: What if I receive a damaged product? | answer: Please email photos of the damage within 48...
#   [2.98s]   Doc 4 [techmart_faq.csv]: question: Do you price match if the item goes on sale later? | answer: Yes, request a one‑time price...
#   [2.98s]   Doc 5 [techmart_faq.csv]: question: When will I receive my refund? | answer: Refunds are processed 3–5 business days after we ...
#   [2.98s] Evaluating 5 documents for query: What are your return policies?
#   [2.98s] Evaluating 5 documents for query: What are your return policies?
#   [8.65s] ✓ Relevant doc: The document directly describes a return policy, including a 30-day return window and full refund conditions, which helps answer the query about return policies.
#   [8.65s] ✓ Relevant doc: The document provides return-related policy details, including free return shipping for defective items and a fee for change-of-mind returns, which directly helps answer the query about return policies.
#   [8.65s] ✓ Relevant doc: The document is about returns-related support for damaged products, including replacement and pickup steps, so it helps answer a return-policy query.
#   [8.65s] ✗ Irrelevant doc: The document is about price matching and one-time price adjustments within 14 days, not return policies or returns/exchanges.
#   [8.65s] ✓ Relevant doc: The document is about returns and refunds, which is directly relevant to a query asking about return policies. It provides policy details on refund timing after a return is inspected.
#   [8.65s] Document evaluation complete: 4/5 relevant
#   [8.65s] Query Quality Assessment:
#   [8.65s] Relevant docs: 4/5
#   [8.65s] Found 4 relevant docs, no retry needed
#   [8.65s] No rewrite needed or found relevant documents, proceeding to generation
#   [8.65s] Generating answer for subquery: What are your return policies?
#   [10.77s] Generated subquery answer: TechMart’s return policy is:
#
# - **Return window:** Most products can be returned in **like-new condition within 30 days of delivery** for a full refund.
# - **Return shipping:** **Free** for **defective items**. For **change-of-mind returns**, **USD 7** is deducted from the refund.
# - **Damaged products:** If you receive a damaged item, email photos of the damage within **48 hours** and TechMart will arrange a **free pickup and replacement**.
# - **Refund timing:** Refunds are processed **3–5 business days** after the returned item is inspected and are sent to your **original payment method**.
#   [10.77s] Completed processing for query: What are your return policies?
# ================================================================================
#
# ================================================================================
# Query Processing Summary:
#   Total queries processed: 2
#   Total documents retrieved: 8
#   Execution strategy: parallel
# ================================================================================
# Generating final answer with 8 total documents
# Generated final answer
#
# ====================================================================================================
# FINAL ANSWER:
# ====================================================================================================
# Here are the Intel i7 laptops currently in the TechMart catalog:
#
# 1. **ZenithBook 11 Evo** — **$1,299**
#    - **CPU:** Intel Core i7-1360P (12-core, up to 5.0GHz)
#    - **RAM:** 16GB
#    - **Storage:** 512GB
#    - **Display:** 11" QHD+ (2560x1600), 400 nits, IPS, 100% sRGB
#    - **Battery:** 13 hours
#    - **Weight:** 1.35 kg
#
# 2. **ZenithBook 12 Evo** — **$1,299**
#    - **CPU:** Intel Core i7-1360P (12-core, up to 5.0GHz)
#    - **RAM:** 16GB
#    - **Storage:** 512GB
#    - **Display:** 12.6-inch IPS, 2880x1620, 400 nits, 100% sRGB
#    - **Battery:** 12 hours
#    - **Weight:** 1.42 kg
#
# 3. **ZenithBook 13 Evo** — **$1,299**
#    - **CPU:** Intel Core i7-1360P (12-core, up to 5.0GHz)
#    - **RAM:** 16GB
#    - **Storage:** 512GB
#    - **Display:** 13.6-inch FHD+ (1920x1200) IPS, 400 nits, 100% sRGB
#    - **Battery:** 13 hours
#    - **Weight:** 1.45 kg
#
# 4. **AeroLite 15 Slim Laptop** — **$1,249**
#    - **CPU:** Intel Core i7-1360P (12-core, up to 5.0GHz)
#    - **RAM:** 16GB
#    - **Storage:** 512GB
#    - **Display:** 15.6-inch FHD IPS (1920x1080), 400 nits, 100% sRGB, anti-glare
#    - **Battery:** 13 hours
#    - **Weight:** 1.29 kg
#
# ## Return policy
# - **Return window:** Most products can be returned in **like-new condition within 30 days of delivery** for a full refund.
# - **Return shipping:**
#   - **Free** for defective items
#   - For **change-of-mind returns**, **USD 7** is deducted from the refund
# - **Damaged product:** Email photos of the damage **within 48 hours**; TechMart will arrange a **free pickup and replacement**
# - **Refund timing:** Refunds are processed **3–5 business days** after the returned item is inspected, and go back to your **original payment method**
#
# If you want, I can also help compare these four i7 laptops by size, weight, battery life, or price.
# ====================================================================================================
# Query processing completed successfully!
# ====================================================================================================
# Query Decomposition Analysis:
#   Needs Decomposition: True
#   Sub-queries: ['What laptops do you have with Intel i7 processors?', 'What are your return policies?']
#   Execution Plan: parallel
#   Reasoning: The query contains two distinct, independent questions: product availability filtered by CPU type and store return policy. They span different domains (catalog/product search vs. policy information) and do not depend on each other, so they should be decomposed and executed in parallel.
#
# Executing 2 queries in parallel
# ================================================================================
# Parallel Query Processing
# ================================================================================
#
# --- Task: What laptops do you have with Intel i7 processors? ---
#   [0.00s] Starting processing for query: What laptops do you have with Intel i7 processors?
#   [0.00s] Skipping query rewrite for: What laptops do you have with Intel i7 processors?
#   [1.54s] Routing query: What laptops do you have with Intel i7 processors?
#   [1.54s] Reasoning: The query asks for product availability and specifications (laptops with Intel i7 processors), which is best answered from the product catalog.
#   [2.13s] Retrieved 5 documents from catalog
#   [2.13s]   Doc 1 [techmart_catalog.csv]: product_id: SKU232 | name: ZenithBook 11 Evo | category: Laptop | price: 1299.0 | short_desc: A slee...
#   [2.13s]   Doc 2 [techmart_catalog.csv]: product_id: SKU177 | name: ZenithBook 12 Evo | category: Laptop | price: 1299.0 | short_desc: 15.6" ...
#   [2.13s]   Doc 3 [techmart_catalog.csv]: product_id: SKU057 | name: ZenithBook 13 Evo | category: Laptop | price: 1299.0 | short_desc: Sleek ...
#   [2.13s]   Doc 4 [techmart_catalog.csv]: product_id: SKU254 | name: AeroLite 15 Slim Laptop | category: Laptop | price: 1249.0 | short_desc: ...
#   [2.13s]   Doc 5 [techmart_catalog.csv]: product_id: SKU028 | name: ZenLite 15 Evo Laptop | category: Laptop | price: 1199.0 | short_desc: Sl...
#   [2.13s] Evaluating 5 documents for query: What laptops do you have with Intel i7 processors?
#   [2.13s] Evaluating 5 documents for query: What laptops do you have with Intel i7 processors?
#   [4.30s] ✓ Relevant doc: The document is for a laptop product and explicitly lists an Intel Core i7 processor (i7-1360P), which directly helps answer the query about laptops with Intel i7 processors.
#   [4.30s] ✓ Relevant doc: The document describes a laptop product and explicitly states it is powered by an Intel Core i7 processor, which directly helps answer the query about laptops with Intel i7 processors.
#   [4.30s] ✓ Relevant doc: The document describes a laptop product with an Intel Core i7 processor, which directly helps answer the query about laptops with Intel i7 processors.
#   [4.30s] ✓ Relevant doc: The document describes a laptop product with an Intel Core i7 processor, which directly matches the query asking for laptops with Intel i7 processors.
#   [4.30s] ✗ Irrelevant doc: The query asks for laptops with Intel i7 processors, but this document describes a laptop with an Intel Core i5 processor (Intel Core i5-1340P). It does not help identify i7 models.
#   [4.30s] Document evaluation complete: 4/5 relevant
#   [4.30s] Query Quality Assessment:
#   [4.30s] Relevant docs: 4/5
#   [4.30s] Found 4 relevant docs, no retry needed
#   [4.30s] No rewrite needed or found relevant documents, proceeding to generation
#   [4.30s] Generating answer for subquery: What laptops do you have with Intel i7 processors?
#   [6.69s] Generated subquery answer: We have these laptops with Intel Core i7 processors:
#
# - **ZenithBook 11 Evo** — **$1,299**
#   - Intel Core i7-1360P
#   - 16GB RAM, 512GB storage
#   - 11" QHD+ display
#   - 13-hour battery life
#
# - **ZenithBook 12 Evo** — **$1,299**
#   - Intel Core i7-1360P
#   - 16GB RAM, 512GB storage
#   - 12.6" IPS display
#   - 12-hour battery life
#
# - **ZenithBook 13 Evo** — **$1,299**
#   - Intel Core i7-1360P
#   - 16GB RAM, 512GB storage
#   - 13.6" FHD+ display
#   - 13-hour battery life
#
# - **AeroLite 15 Slim Laptop** — **$1,249**
#   - Intel Core i7-1360P
#   - 16GB RAM, 512GB storage
#   - 15.6" FHD IPS display
#   - 13-hour battery life
#
# If you want, I can also compare them by screen size, weight, or battery life.
#   [6.69s] Completed processing for query: What laptops do you have with Intel i7 processors?
#
# --- Task: What are your return policies? ---
#   [0.00s] Starting processing for query: What are your return policies?
#   [0.00s] Skipping query rewrite for: What are your return policies?
#   [1.94s] Routing query: What are your return policies?
#   [1.94s] Reasoning: The query asks about return policies, which is customer service/policy information best handled by the FAQ collection.
#   [3.15s] Retrieved 5 documents from FAQ
#   [3.15s]   Doc 1 [techmart_faq.csv]: question: What is your return window? | answer: Most products can be returned in like‑new condition ...
#   [3.15s]   Doc 2 [techmart_faq.csv]: question: Is return shipping free? | answer: Return shipping is free for defective items; for change...
#   [3.15s]   Doc 3 [techmart_faq.csv]: question: What if I receive a damaged product? | answer: Please email photos of the damage within 48...
#   [3.15s]   Doc 4 [techmart_faq.csv]: question: Do you price match if the item goes on sale later? | answer: Yes, request a one‑time price...
#   [3.15s]   Doc 5 [techmart_faq.csv]: question: When will I receive my refund? | answer: Refunds are processed 3–5 business days after we ...
#   [3.15s] Evaluating 5 documents for query: What are your return policies?
#   [3.15s] Evaluating 5 documents for query: What are your return policies?
#   [4.58s] ✓ Relevant doc: The document directly describes the return policy by stating the return window and refund condition, which helps answer the user's question about return policies.
#   [4.58s] ✓ Relevant doc: The document directly addresses part of the return policy by explaining return shipping costs for defective items and change-of-mind returns, which helps answer the user’s question.
#   [4.58s] ✓ Relevant doc: The document describes a returns-related policy for damaged products, including replacement and pickup steps, which helps answer a general question about return policies.
#   [4.58s] ✗ Irrelevant doc: The document is about price matching and price adjustments after purchase, not return policies. It does not provide information on returns, refunds, or return conditions.
#   [4.58s] ✓ Relevant doc: The document is about refunds in the returns process, which directly helps answer a query about return policies.
#   [4.58s] Document evaluation complete: 4/5 relevant
#   [4.58s] Query Quality Assessment:
#   [4.58s] Relevant docs: 4/5
#   [4.58s] Found 4 relevant docs, no retry needed
#   [4.58s] No rewrite needed or found relevant documents, proceeding to generation
#   [4.58s] Generating answer for subquery: What are your return policies?
#   [6.20s] Generated subquery answer: TechMart’s return policy is:
#
# - **Return window:** Most products can be returned in **like-new condition within 30 days of delivery** for a full refund.
# - **Return shipping:** **Free for defective items**. For **change-of-mind returns**, **USD 7** is deducted from the refund.
# - **Damaged products:** Email **photos of the damage within 48 hours** so TechMart can arrange a **free pickup and replacement**.
# - **Refund timing:** Refunds are processed **3–5 business days after the returned item is inspected** and go back to your **original payment method**.
#
#
#   [6.20s] Completed processing for query: What are your return policies?
# ================================================================================
#
# ================================================================================
# Query Processing Summary:
#   Total queries processed: 2
#   Total documents retrieved: 8
#   Execution strategy: parallel
# ================================================================================
# Generating final answer with 8 total documents
# Generated final answer
#
# ====================================================================================================
# FINAL ANSWER:
# ====================================================================================================
# Here are the Intel Core i7 laptops currently in TechMart’s catalog:
#
# 1. **ZenithBook 11 Evo** — **$1,299**
#    - **CPU:** Intel Core i7-1360P (12-core, up to 5.0GHz)
#    - **RAM:** 16GB
#    - **Storage:** 512GB
#    - **Display:** 11" QHD+ (2560x1600), 400 nits, IPS, 100% sRGB
#    - **Battery:** 13 hours
#    - **Weight:** 1.35 kg
#
# 2. **ZenithBook 12 Evo** — **$1,299**
#    - **CPU:** Intel Core i7-1360P (12-core, up to 5.0GHz)
#    - **RAM:** 16GB
#    - **Storage:** 512GB
#    - **Display:** 12.6-inch IPS, 2880x1620, 400 nits, 100% sRGB
#    - **Battery:** 12 hours
#    - **Weight:** 1.42 kg
#
# 3. **ZenithBook 13 Evo** — **$1,299**
#    - **CPU:** Intel Core i7-1360P (12-core, up to 5.0GHz)
#    - **RAM:** 16GB
#    - **Storage:** 512GB
#    - **Display:** 13.6-inch FHD+ (1920x1200) IPS, 400 nits, 100% sRGB
#    - **Battery:** 13 hours
#    - **Weight:** 1.45 kg
#
# 4. **AeroLite 15 Slim Laptop** — **$1,249**
#    - **CPU:** Intel Core i7-1360P (12-core, up to 5.0GHz)
#    - **RAM:** 16GB
#    - **Storage:** 512GB
#    - **Display:** 15.6-inch FHD IPS (1920x1080), 400 nits, 100% sRGB, anti-glare
#    - **Battery:** 13 hours
#    - **Weight:** 1.29 kg
#
# ### Return policy
# - **Return window:** Most products can be returned in **like-new condition within 30 days of delivery** for a full refund.
# - **Return shipping:**
#   - **Free** for defective items
#   - For **change-of-mind** returns, **USD 7** is deducted from the refund
# - **Damaged products:** Email photos of the damage within **48 hours**; TechMart will arrange a **free pickup and replacement**
# - **Refund timing:** Refunds are processed **3–5 business days** after the returned item is inspected and are credited back to the **original payment method**
#
# If you want, I can also help compare these i7 laptops by size, battery life, or portability.
# ====================================================================================================
# Query processing completed successfully!
# ====================================================================================================

# %%
# Test with sequential decomposition query - now with context-aware enhancement
await ask_adaptive_rag("Find me the best mouse you have then check if it has any issues")
# Out:
# ====================================================================================================
# ADAPTIVE RAG QUERY: Find me the best mouse you have then check if it has any issues
# ====================================================================================================
# Query Decomposition Analysis:
#   Needs Decomposition: True
#   Sub-queries: ['Find the best mouse you have', 'Check if it has any issues']
#   Execution Plan: sequential
#   Reasoning: The query has two parts: first identify a mouse, then evaluate that selected mouse for issues. The second part depends on the result of the first, so decomposition is needed and should be executed sequentially.
#
# Executing 2 queries sequentially
#
# --- Sequential Step 1/2 ---
#
# Step 1 Processing Details:
#   [0.00s] Starting processing for query: Find the best mouse you have
#   [0.00s] Skipping query rewrite for: Find the best mouse you have
#   [1.17s] Routing query: Find the best mouse you have
#   [1.17s] Reasoning: The query asks for product recommendations ('best mouse you have'), which falls under product information and recommendations. The catalog collection is the most relevant source.
#   [1.73s] Retrieved 5 documents from catalog
#   [1.73s]   Doc 1 [techmart_catalog.csv]: product_id: SKU286 | name: GlideMax Wireless Mouse | category: Mouse | price: 69.99 | short_desc: Er...
#   [1.73s]   Doc 2 [techmart_catalog.csv]: product_id: SKU142 | name: GlideMaster MX Wireless Mouse | category: Mouse | price: 79.99 | short_de...
#   [1.73s]   Doc 3 [techmart_catalog.csv]: product_id: SKU173 | name: GlideMaster MX Wireless Mouse | category: Mouse | price: 89.99 | short_de...
#   [1.73s]   Doc 4 [techmart_catalog.csv]: product_id: SKU161 | name: GlideMaster MX Wireless Mouse | category: Mouse | price: 79.99 | short_de...
#   [1.73s]   Doc 5 [techmart_catalog.csv]: product_id: SKU042 | name: GlideMaster MX Wireless Mouse | category: Mouse | price: 89.99 | short_de...
#   [1.73s] Evaluating 5 documents for query: Find the best mouse you have
#   [1.73s] Evaluating 5 documents for query: Find the best mouse you have
#   [3.33s] ✓ Relevant doc: The document is about a mouse product and provides key features like high DPI, wireless support, ergonomic design, and battery life, which help evaluate whether it could be the best mouse.
#   [3.33s] ✓ Relevant doc: The document is about a mouse product and provides key features, specs, and price that help assess whether it could be the best mouse. It directly matches the query intent.
#   [3.33s] ✓ Relevant doc: The document is about a mouse product and includes detailed features and specs, which could help identify a strong candidate for the user's request to find the best mouse.
#   [3.33s] ✓ Relevant doc: The document is about a mouse product and provides features and specs that could help determine whether it is a strong candidate for the 'best mouse' among available options.
#   [3.33s] ✓ Relevant doc: The document describes a mouse product with strong features (wireless, high-precision sensor, long battery life, customizable buttons), which could help answer a query asking for the best mouse. It is directly relevant to finding a good mouse option.
#   [3.33s] Document evaluation complete: 5/5 relevant
#   [3.33s] Query Quality Assessment:
#   [3.33s] Relevant docs: 5/5
#   [3.33s] Found 5 relevant docs, no retry needed
#   [3.33s] No rewrite needed or found relevant documents, proceeding to generation
#   [3.33s] Generating answer for subquery: Find the best mouse you have
#   [4.93s] Generated subquery answer: The best mouse in TechMart’s catalog appears to be the **GlideMaster MX Wireless Mouse (SKU042)**.
#
# **Why it stands out:**
# - **Price:** $89.99
# - **DPI:** 16,000
# - **Sensor:** PixArt PAW3370
# - **Buttons:** 7
# - **Wireless:** Yes
# - **Battery life:** 120 hours
# - **Weight:** 83 g
# - **Highlights:** High-precision sensor, long battery life, customizable buttons, suitable for productivity and gaming
#
# If you want, I can also compare it with the other GlideMaster MX versions to help you pick the best value.
#   [4.94s] Completed processing for query: Find the best mouse you have
#
# --- Sequential Step 2/2 ---
#
# Step 2 Processing Details:
#   [0.00s] Starting processing for query: Check if it has any issues
#   [0.00s] Rewriting query with context: Check if it has any issues
#   [0.00s] Previous context: Step 1 result: The best mouse in TechMart’s catalog appears to be the **GlideMaster MX Wireless Mouse (SKU042)**.
#
# **Why it stands out:**
# - **Price:** $89.99
# - **DPI:** 16,000
# - **Sensor:** PixArt PAW3370
# - **Buttons:** 7
# - **Wireless:** Yes
# - **Battery life:** 120 hours
# - **Weight:** 83 g
# - **Highlights:** High-precision sensor, long battery life, customizable buttons, suitable for productivity and gaming
#
# If you want, I can also compare it with the other GlideMaster MX versions to help you pick the best value.
#
#   [2.80s] Original query: Check if it has any issues
#   [2.80s] Rewritten query: Check if the GlideMaster MX Wireless Mouse (SKU042) has any known issues, common problems, defects, troubleshooting notes, or customer complaints in TechMart’s product, support, or troubleshooting information.
#   [2.80s] Improvements: Resolved the ambiguity in 'it' by replacing it with the specific product from prior context: GlideMaster MX Wireless Mouse (SKU042). Expanded 'issues' into clearer retrieval terms such as known issues, common problems, defects, troubleshooting notes, and customer complaints. Added TechMart-specific sources to better target relevant store documents.
#   [4.46s] Routing query: Check if the GlideMaster MX Wireless Mouse (SKU042) has any known issues, common problems, defects, troubleshooting notes, or customer complaints in TechMart’s product, support, or troubleshooting information.
#   [4.46s] Reasoning: The query is asking about known issues, common problems, defects, troubleshooting notes, and support-related information for a specific TechMart product. That maps most directly to the troubleshooting collection. Although the product is identified by SKU, the request is not primarily about product specs or policies, and it does not require current internet information, so catalog, faq, and web_search are less relevant.
#   [5.24s] Retrieved 5 documents from troubleshooting
#   [5.24s]   Doc 1 [techmart_troubleshooting.csv]: issue_title: GlideMaster MX Mouse Not Charging or Powering On | product_id: SKU109 | symptoms: The m...
#   [5.24s]   Doc 2 [techmart_troubleshooting.csv]: issue_title: Mouse Pointer Lagging or Stuttering During Use | product_id: SKU236 | symptoms: While m...
#   [5.24s]   Doc 3 [techmart_troubleshooting.csv]: issue_title: Mouse Pointer Lag or Stuttering During Use | product_id: SKU102 | symptoms: While using...
#   [5.24s]   Doc 4 [techmart_troubleshooting.csv]: issue_title: GlideMouse Wireless DPI button non‑responsive | product_id: SKU010 | symptoms: Pressing...
#   [5.24s]   Doc 5 [techmart_troubleshooting.csv]: issue_title: Mouse Double-Clicks When Single Clicked | product_id: SKU236 | symptoms: When performin...
#   [5.24s] Evaluating 5 documents for query: Check if the GlideMaster MX Wireless Mouse (SKU042) has any known issues, common problems, defects, troubleshooting notes, or customer complaints in TechMart’s product, support, or troubleshooting information.
#   [5.24s] Evaluating 5 documents for query: Check if the GlideMaster MX Wireless Mouse (SKU042) has any known issues, common problems, defects, troubleshooting notes, or customer complaints in TechMart’s product, support, or troubleshooting information.
#   [7.00s] ✗ Irrelevant doc: The document is about GlideMaster MX Mouse SKU109 with a charging/power issue, but the query asks specifically about GlideMaster MX Wireless Mouse SKU042 and any known issues in TechMart information. Because the SKU/model referenced is different and the document does not clearly establish it as the same product family or variant, it is not reliably relevant.
#   [7.00s] ✗ Irrelevant doc: The document is about the GlidePro X9 Wireless Mouse (SKU236), which is a different product line from the queried GlideMaster MX Wireless Mouse (SKU042). Although it discusses a mouse issue and troubleshooting steps, it does not provide information relevant to the specific product family asked about.
#   [7.00s] ✗ Irrelevant doc: The document is about the GlideTech Pulse X Wireless Mouse (SKU102), which is a different product line from the queried GlideMaster MX Wireless Mouse (SKU042). It does not provide known issues or troubleshooting information for the GlideMaster MX.
#   [7.00s] ✓ Relevant doc: The document is about a GlideMouse wireless mouse issue and troubleshooting steps, which is likely the same product family as the queried GlideMaster MX Wireless Mouse. It provides known problems, fixes, and support notes relevant to assessing issues for this type of mouse.
#   [7.00s] ✗ Irrelevant doc: The document is about the GlidePro X9 Wireless Mouse (SKU236), which is a different product family from the GlideMaster MX Wireless Mouse (SKU042). It does describe a mouse double-click issue and troubleshooting steps, but it does not appear to apply to the queried product.
#   [7.00s] Document evaluation complete: 1/5 relevant
#   [7.00s] Query Quality Assessment:
#   [7.00s] Relevant docs: 1/5
#   [7.00s] Found 1 relevant docs, no retry needed
#   [7.00s] No rewrite needed or found relevant documents, proceeding to generation
#   [7.00s] Generating answer for subquery: Check if the GlideMaster MX Wireless Mouse (SKU042) has any known issues, common problems, defects, troubleshooting notes, or customer complaints in TechMart’s product, support, or troubleshooting information.
#   [9.97s] Generated subquery answer: I couldn’t find any TechMart support or troubleshooting information specifically for the **GlideMaster MX Wireless Mouse (SKU042)**.
#
# The only related document is for a different product, the **GlideMouse Wireless (SKU010)**, which mentions a **non-responsive DPI button** and suggests troubleshooting like resetting the mouse, checking button mapping, updating firmware, or replacing the top shell if there’s a hardware fault.
#
# So, based on the documents provided, there are **no confirmed known issues, defects, or customer complaints listed for SKU042**.
#   [9.97s] Completed processing for query: Check if it has any issues
#
# ================================================================================
# Query Processing Summary:
#   Total queries processed: 2
#   Total documents retrieved: 6
#   Execution strategy: sequential
# ================================================================================
# Generating final answer with 6 total documents
# Generated final answer
#
# ====================================================================================================
# FINAL ANSWER:
# ====================================================================================================
# The best mouse in the results looks to be the **GlideMaster MX Wireless Mouse (SKU042)**.
#
# Why this one stands out:
# - **Price:** $89.99
# - **DPI:** **16,000**
# - **Sensor:** **PixArt PAW3370**
# - **Buttons:** 7
# - **Wireless:** Yes
# - **Battery life:** **120 hours**
# - **Weight:** 83 g
# - **Use case:** Good for both **productivity and gaming**
#
# Possible issue check:
# - I found **one troubleshooting entry**, but it is for **SKU010 (GlideMouse Wireless DPI button non-responsive)**, **not** the GlideMaster MX.
# - So there are **no documented issues in the provided context for the GlideMaster MX Wireless Mouse**.
#
# If you want, I can also compare the top mouse against the other mouse options and explain why it’s the best pick.
# ====================================================================================================
# Query processing completed successfully!
# ====================================================================================================
# Query Decomposition Analysis:
#   Needs Decomposition: True
#   Sub-queries: ['Find me the best mouse you have', 'Check if it has any issues']
#   Execution Plan: sequential
#   Reasoning: The query contains two distinct tasks with a dependency: first identify the best mouse, then evaluate issues for that specific mouse. The second sub-query depends on the result of the first, so decomposition is needed with a sequential execution plan.
#
# Executing 2 queries sequentially
#
# --- Sequential Step 1/2 ---
# Step 1 Processing Details:
#   [0.00s] Starting processing for query: Find me the best mouse you have
#   [0.00s] Skipping query rewrite for: Find me the best mouse you have
#   [1.41s] Routing query: Find me the best mouse you have
#   [1.41s] Reasoning: The user is asking for product recommendations ('best mouse you have'), which is best answered using the product catalog rather than FAQ or troubleshooting.
#   [1.98s] Retrieved 5 documents from catalog
#   [1.98s]   Doc 1 [techmart_catalog.csv]: product_id: SKU286 | name: GlideMax Wireless Mouse | category: Mouse | price: 69.99 | short_desc: Er...
#   [1.98s]   Doc 2 [techmart_catalog.csv]: product_id: SKU223 | name: GlideX Pro Wireless Mouse | category: Mouse | price: 79.99 | short_desc: ...
#   [1.98s]   Doc 3 [techmart_catalog.csv]: product_id: SKU142 | name: GlideMaster MX Wireless Mouse | category: Mouse | price: 79.99 | short_de...
#   [1.98s]   Doc 4 [techmart_catalog.csv]: product_id: SKU173 | name: GlideMaster MX Wireless Mouse | category: Mouse | price: 89.99 | short_de...
#   [1.98s]   Doc 5 [techmart_catalog.csv]: product_id: SKU042 | name: GlideMaster MX Wireless Mouse | category: Mouse | price: 89.99 | short_de...
#   [1.98s] Evaluating 5 documents for query: Find me the best mouse you have
#   [1.98s] Evaluating 5 documents for query: Find me the best mouse you have
#   [3.62s] ✓ Relevant doc: The document is directly about a mouse product and includes key features like wireless connectivity, high DPI, and battery life, which are useful for determining whether it may be the best mouse.
#   [3.62s] ✓ Relevant doc: The document is about a mouse product and includes key details like price, wireless capability, sensor, DPI, and battery life, which help evaluate whether it could be the 'best mouse'.
#   [3.62s] ✓ Relevant doc: The document describes a mouse product with detailed features, price, and specs, which directly helps answer a request for the best mouse. It is clearly relevant to the query.
#   [3.62s] ✓ Relevant doc: The document is about a mouse product and includes detailed features like wireless connectivity, ergonomic design, sensor, battery life, and price, which can help evaluate whether it is the best mouse option.
#   [3.62s] ✓ Relevant doc: The document is about a mouse product and includes key features like ergonomics, wireless connectivity, high-precision sensor, and battery life, which directly help evaluate whether it could be the 'best mouse'.
#   [3.62s] Document evaluation complete: 5/5 relevant
#   [3.62s] Query Quality Assessment:
#   [3.62s] Relevant docs: 5/5
#   [3.62s] Found 5 relevant docs, no retry needed
#   [3.62s] No rewrite needed or found relevant documents, proceeding to generation
#   [3.62s] Generating answer for subquery: Find me the best mouse you have
#   [6.66s] Generated subquery answer: The best mouse in the catalog appears to be the **GlideMaster MX Wireless Mouse (SKU142)**.
#
# **Why it stands out:**
# - **16,000 DPI** for very high precision
# - **PixArt PMW3389 Optical** sensor
# - **7 buttons**
# - **Wireless**
# - **120-hour battery life**
# - **82 g** weight
# - Price: **$79.99**
#
# It’s also described as suitable for **both productivity and gaming**, with **silent clicks** and long battery life.
#   [6.66s] Completed processing for query: Find me the best mouse you have
#
# --- Sequential Step 2/2 ---
# Step 2 Processing Details:
#   [0.00s] Starting processing for query: Check if it has any issues
#   [0.00s] Rewriting query with context: Check if it has any issues
#   [0.00s] Previous context: Step 1 result: The best mouse in the catalog appears to be the **GlideMaster MX Wireless Mouse (SKU142)**.
#
# **Why it stands out:**
# - **16,000 DPI** for very high precision
# - **PixArt PMW3389 Optical** sensor
# - **7 buttons**
# - **Wireless**
# - **120-hour battery life**
# - **82 g** weight
# - Price: **$79.99**
#
# It’s also described as suitable for **both productivity and gaming**, with **silent clicks** and long battery life.
#
#   [1.99s] Original query: Check if it has any issues
#   [1.99s] Rewritten query: Check whether the GlideMaster MX Wireless Mouse (SKU142) has any known issues, problems, defects, user complaints, or troubleshooting concerns, including build quality, sensor performance, wireless connectivity, battery life, or silent click reliability.
#   [1.99s] Improvements: Incorporated the specific product name and SKU from the prior context, and expanded the vague phrase 'has any issues' into concrete retrieval terms such as known issues, defects, user complaints, and troubleshooting concerns. Also added likely problem areas relevant to a wireless gaming/productivity mouse to improve document matching.
#   [3.58s] Routing query: Check whether the GlideMaster MX Wireless Mouse (SKU142) has any known issues, problems, defects, user complaints, or troubleshooting concerns, including build quality, sensor performance, wireless connectivity, battery life, or silent click reliability.
#   [3.58s] Reasoning: The query asks about known issues, defects, user complaints, and troubleshooting concerns for a specific TechMart product (GlideMaster MX Wireless Mouse, SKU142). This is best answered from the internal troubleshooting collection, which should contain product-specific problem reports and support guidance. No current external software/driver information is requested, so web_search is not needed.
#   [4.18s] Retrieved 5 documents from troubleshooting
#   [4.18s]   Doc 1 [techmart_troubleshooting.csv]: issue_title: GlideMaster MX Mouse Not Charging or Powering On | product_id: SKU109 | symptoms: The m...
#   [4.18s]   Doc 2 [techmart_troubleshooting.csv]: issue_title: Mouse Pointer Lagging or Stuttering During Use | product_id: SKU236 | symptoms: While m...
#   [4.18s]   Doc 3 [techmart_troubleshooting.csv]: issue_title: Mouse Pointer Lag or Stuttering During Use | product_id: SKU102 | symptoms: While using...
#   [4.18s]   Doc 4 [techmart_troubleshooting.csv]: issue_title: GlideMouse Wireless DPI button non‑responsive | product_id: SKU010 | symptoms: Pressing...
#   [4.18s]   Doc 5 [techmart_troubleshooting.csv]: issue_title: Mouse Double-Clicks When Single Clicked | product_id: SKU236 | symptoms: When performin...
#   [4.18s] Evaluating 5 documents for query: Check whether the GlideMaster MX Wireless Mouse (SKU142) has any known issues, problems, defects, user complaints, or troubleshooting concerns, including build quality, sensor performance, wireless connectivity, battery life, or silent click reliability.
#   [4.18s] Evaluating 5 documents for query: Check whether the GlideMaster MX Wireless Mouse (SKU142) has any known issues, problems, defects, user complaints, or troubleshooting concerns, including build quality, sensor performance, wireless connectivity, battery life, or silent click reliability.
#   [5.83s] ✗ Irrelevant doc: The document is about GlideMaster MX Mouse SKU109 not charging or powering on, which is a different SKU than the queried GlideMaster MX Wireless Mouse SKU142. It describes a specific power failure issue rather than broader complaints or known issues for SKU142.
#   [5.83s] ✓ Relevant doc: The document is about a wireless mouse in the same product family and discusses a relevant troubleshooting issue: pointer lagging/stuttering, which relates to sensor performance and wireless connectivity concerns. Even though the SKU and model name differ, it can help answer the query about known issues and complaints for the target mouse family.
#   [5.83s] ✗ Irrelevant doc: The document is about the GlideTech Pulse X Wireless Mouse (SKU102), which is a different product line from the GlideMaster MX Wireless Mouse (SKU142). Although it discusses mouse lag/sensor troubleshooting, it does not provide information about the queried product’s known issues or complaints.
#   [5.83s] ✓ Relevant doc: The document is about a GlideMouse Wireless product issue and includes troubleshooting for a specific defect, which is relevant to checking known issues/complaints on the GlideMaster MX Wireless Mouse family, even though the SKU differs and the problem is not the exact same feature set.
#   [5.83s] ✗ Irrelevant doc: The document is about the GlidePro X9 Wireless Mouse (SKU236) and a double-click issue. The query asks about the GlideMaster MX Wireless Mouse (SKU142) and its potential issues, which is a different product line, so this document is not relevant.
#   [5.83s] Document evaluation complete: 2/5 relevant
#   [5.83s] Query Quality Assessment:
#   [5.83s] Relevant docs: 2/5
#   [5.83s] Found 2 relevant docs, no retry needed
#   [5.83s] No rewrite needed or found relevant documents, proceeding to generation
#   [5.83s] Generating answer for subquery: Check whether the GlideMaster MX Wireless Mouse (SKU142) has any known issues, problems, defects, user complaints, or troubleshooting concerns, including build quality, sensor performance, wireless connectivity, battery life, or silent click reliability.
#   [7.77s] Generated subquery answer: I couldn’t find any document in the provided context that mentions **GlideMaster MX Wireless Mouse (SKU142)** specifically.
#
# What I *did* find were issues for other mice:
# - **SKU236 (GlidePro X9 Wireless Mouse):** reports of **pointer lag/stuttering** with troubleshooting focused on battery charge, wireless interference, dongle placement, sensor cleaning, and surface issues.
# - **SKU010 (GlideMouse Wireless):** a **non-responsive DPI button** with a firmware/button-mapping troubleshooting path.
#
# So, based on the available documents, there are **no confirmed known issues, defects, or complaint records for SKU142** covering build quality, sensor performance, wireless connectivity, battery life, or silent click reliability. If you want, I can also help draft a support checklist for SKU142 in case you’re investigating a customer report.
#   [7.77s] Completed processing for query: Check if it has any issues
#
# ================================================================================
# Query Processing Summary:
#   Total queries processed: 2
#   Total documents retrieved: 7
#   Execution strategy: sequential
# ================================================================================
# Generating final answer with 7 total documents
# Generated final answer
#
# ====================================================================================================
# FINAL ANSWER:
# ====================================================================================================
# The **best mouse** in the retrieved catalog looks like the **GlideMaster MX Wireless Mouse (SKU142)**.
#
# ### Why this one stands out
# - **Price:** $79.99
# - **DPI:** **16,000**
# - **Sensor:** **PixArt PMW3389 Optical**
# - **Buttons:** 7
# - **Wireless:** Yes
# - **Battery life:** **120 hours**
# - **Weight:** 82 g
#
# It has the strongest overall mix of high DPI, a premium sensor, long battery life, and a solid ergonomic design.
#
# ### Any issues with it?
# I checked the troubleshooting info, but there is **no issue document specifically for SKU142 / GlideMaster MX Wireless Mouse**. The only mouse issue found was for a different model:
#
# - **SKU236 – GlidePro X9 Wireless Mouse**
#   - Issue: pointer lagging or stuttering
#   - Fixes include charging it, moving the dongle, reducing interference, cleaning the sensor, trying a different surface, updating drivers, and testing on another computer
#
# ### What this means for the GlideMaster MX
# - I **did not find any known issues** for the GlideMaster MX in the provided documents.
# - Since no product-specific issue was listed, I can’t confirm any defects or common problems for that mouse from the available data.
#
# If you want, I can also compare the top 2–3 mice in the catalog so you can choose the best one for gaming, productivity, or battery life.
# ====================================================================================================
# Query processing completed successfully!
# ====================================================================================================

# %%
# Test with web search query
await ask_adaptive_rag("Windows 11 blue screen error 0x0000007E - how do I fix this?")
# Out:
# ====================================================================================================
# ADAPTIVE RAG QUERY: Windows 11 blue screen error 0x0000007E - how do I fix this?
# ====================================================================================================
# Query Decomposition Analysis:
#   Needs Decomposition: False
#   Reasoning: This is a single cohesive troubleshooting question about one Windows error code and its fix. It may be complex, but it does not contain multiple distinct questions or unrelated domains, so it should not be decomposed.
#
# Processing single query: Windows 11 blue screen error 0x0000007E - how do I fix this?
# ================================================================================
# Single Query Processing
# ================================================================================
#
# --- Task: Windows 11 blue screen error 0x0000007E - how do I fix this? ---
#   [0.00s] Starting processing for query: Windows 11 blue screen error 0x0000007E - how do I fix this?
#   [0.00s] Skipping query rewrite for: Windows 11 blue screen error 0x0000007E - how do I fix this?
#   [1.74s] Routing query: Windows 11 blue screen error 0x0000007E - how do I fix this?
#   [1.74s] Reasoning: This is a Windows 11 blue screen error with a specific stop code, which is a current technical troubleshooting issue likely to require up-to-date solutions and may not be covered in TechMart's internal troubleshooting database. Per the routing rules, use web_search for OS/driver-related troubleshooting and current technical problems.
#   [2.64s] Retrieved 5 documents from web search
#   [2.64s]   Doc 1 [https://learn.microsoft.com/en-us/answers/questions/2409526/blue-screen-error-0x0000007e]: # Blue screen, ERROR: 0x0000007e - Microsoft Q&A. Build your AI skills with chances to earn prizes a...
#   [2.64s]   Doc 2 [https://community.spiceworks.com/t/blue-screen-of-death-0x0000007e-have-you-experienced-this/97880]: # Blue Screen Of Death - 0x0000007E , have you experienced this ? I tried to install Windows Xp SP3 ...
#   [2.64s]   Doc 3 [https://www.dell.com/support/contents/en-us/article/product-support/self-support-knowledgebase/fix-common-issues/blue-screen]: # Blue Screen (BSOD) Errors and Stop Code Issues in Windows. ## What is Blue Screen of Death (BSOD)?...
#   [2.64s]   Doc 4 [https://www.youtube.com/watch?v=L_iX1ohoFMU]: How To Fix Blue Screen of Death Stop Error Code 0x0000007e in Windows Support me: https://ko-fi.com/...
#   [2.64s]   Doc 5 [https://www.reddit.com/r/computers/comments/1jnyof/can_anyone_make_sense_of_this_bsod_for_me]: 0x0000007E - The error code described here is a SYSTEM_THREAD_EXCEPTION_NOT_HANDLED error, meaning t...
#   [2.64s] Evaluating 5 documents for query: Windows 11 blue screen error 0x0000007E - how do I fix this?
#   [2.64s] Evaluating 5 documents for query: Windows 11 blue screen error 0x0000007E - how do I fix this?
#   [4.24s] ✓ Relevant doc: The document discusses the same blue screen stop code 0x0000007e and includes troubleshooting steps that could help answer how to fix it, even though it references Vista rather than Windows 11.
#   [4.24s] ✓ Relevant doc: The document discusses BSOD error 0x0000007E and possible fixes such as changing SATA/BIOS mode or checking hardware/media, which can help with the user's Windows 11 blue screen issue even though it references Windows XP.
#   [4.24s] ✓ Relevant doc: The document is about Windows 10/11 blue screen (BSOD) stop code issues and troubleshooting, which directly matches the user’s query about Windows 11 error 0x0000007E and how to fix it.
#   [4.24s] ✓ Relevant doc: The document directly discusses how to fix the Blue Screen of Death stop error code 0x0000007e in Windows, which matches the user’s Windows 11 blue screen error query.
#   [4.24s] ✓ Relevant doc: The document directly explains the Windows blue screen stop code 0x0000007E as a SYSTEM_THREAD_EXCEPTION_NOT_HANDLED error, which is relevant to helping answer the query about fixing this issue.
#   [4.24s] Document evaluation complete: 5/5 relevant
#   [4.24s] Query Quality Assessment:
#   [4.24s] Relevant docs: 5/5
#   [4.24s] Found 5 relevant docs, no retry needed
#   [4.24s] No rewrite needed or found relevant documents, proceeding to generation
#   [4.24s] Generating answer for subquery: Windows 11 blue screen error 0x0000007E - how do I fix this?
#   [7.71s] Generated subquery answer: Error **0x0000007E** is a Windows **BSOD** stop code that’s usually caused by a **driver conflict, corrupt system file, hardware issue, or boot configuration problem**.
#
# ### What to try on Windows 11
# 1. **Restart and boot into Safe Mode**
#    - If Windows won’t boot normally, use **Advanced Startup Options** and choose **Safe Mode**.
#    - In Safe Mode, you can remove recent drivers or software that may be causing the crash.
#
# 2. **Update or roll back drivers**
#    - If the BSOD started after installing new hardware/software, update the related driver.
#    - If it started after a driver update, try **rolling back** that driver.
#
# 3. **Check for corrupt system files**
#    - Run Windows repair tools such as:
#      - **SFC /scannow**
#      - **DISM** repairs
#    - These can fix damaged Windows files that trigger stop errors.
#
# 4. **Check hardware and disk space**
#    - Microsoft notes to make sure you have **adequate disk space**.
#    - Also check for failing RAM, storage issues, or other hardware faults.
#
# 5. **If it happens during boot, inspect BIOS/storage settings**
#    - Some BSODs can be caused by incorrect **SATA mode** settings in BIOS/UEFI.
#    - If applicable, try **AHCI / IDE / compatibility mode** based on your system’s requirements.
#
# 6. **If you can’t get into Windows**
#    - Use **Startup Repair** or a Windows recovery USB.
#    - If needed, restore from a recent restore point.
#
# ### From the Microsoft guidance
# If a driver is mentioned in the stop message, **disable it or check with the manufacturer for updates**. If needed, start in **Safe Mode** to remove or disable problematic components.
#
# If you want, I can also give you a **Windows 11 step-by-step repair checklist** for this stop code.
#   [7.71s] Completed processing for query: Windows 11 blue screen error 0x0000007E - how do I fix this?
# ================================================================================
#
# ================================================================================
# Query Processing Summary:
#   Total queries processed: 1
#   Total documents retrieved: 5
#   Execution strategy: parallel
# ================================================================================
# Generating final answer with 5 total documents
# Generated final answer
#
# ====================================================================================================
# FINAL ANSWER:
# ====================================================================================================
# Windows 11 stop code **0x0000007E** usually means Windows hit a **system thread exception that wasn’t handled**. In practice, it’s often caused by one of these:
#
# - a **bad or incompatible driver**
# - **corrupt system files**
# - **hardware problems** (RAM, storage, etc.)
# - a **boot/configuration issue**
#
# Here’s the best way to fix it, step by step:
#
# ## 1) Try Safe Mode first
# If Windows won’t boot normally:
#
# - Restart the PC
# - Enter **Advanced Startup Options**
# - Choose **Safe Mode**
#
# If it boots in Safe Mode, the cause is often a driver or startup software issue.
#
# ## 2) Check for recent driver changes
# The Microsoft guidance says that if a driver is mentioned in the stop message, you should:
#
# - **disable the driver**
# - or **update it from the manufacturer**
#
# For Windows 11, focus especially on:
# - graphics driver
# - storage/controller driver
# - network driver
# - chipset driver
#
# If you recently installed a driver update, try **rolling it back**.
#
# ## 3) Run Windows Update
# Install all available updates, especially:
# - cumulative updates
# - optional driver updates
#
# These can fix compatibility issues in Windows 11.
#
# ## 4) Repair system files
# If corrupted Windows files are involved, run these in **Command Prompt as Administrator**:
#
# ```cmd
# sfc /scannow
# ```
#
# Then:
#
# ```cmd
# DISM /Online /Cleanup-Image /RestoreHealth
# ```
#
# Restart afterward.
#
# ## 5) Check disk space and storage health
# Microsoft notes to make sure you have **adequate disk space**. Also check:
# - storage drive health
# - file system errors
# - loose or failing SSD/HDD connections
#
# You can run:
#
# ```cmd
# chkdsk /f
# ```
#
# ## 6) Check hardware
# BSODs can also come from hardware issues. If the error keeps happening:
#
# - test **RAM**
# - check SSD/HDD health
# - remove any recently added hardware
# - make sure the PC is not overheating
#
# Dell’s BSOD guidance also notes that **hardware failures** can cause blue screens.
#
# ## 7) If this happened during installation or boot
# One of the retrieved sources mentions that on some systems, a **storage controller mode** mismatch can trigger this error. If you are installing Windows or the crash happens during boot, check BIOS/UEFI settings such as:
#
# - **SATA mode**
# - **AHCI / IDE / compatibility mode**
#
# For Windows 11 systems, changing this should be done carefully, since the wrong setting can make Windows fail to boot.
#
# ## 8) If nothing works
# If the BSOD persists after driver updates, repair commands, and hardware checks, the most likely causes are:
# - a failing SSD/HDD
# - bad RAM
# - an incompatible driver
# - a deeper Windows corruption issue
#
# At that point, a **Windows repair install** or **clean reinstall** may be needed.
#
# If you want, I can give you a **Windows 11-specific step-by-step checklist** to troubleshoot 0x0000007E in the safest order.
# ====================================================================================================
# Query processing completed successfully!
# ====================================================================================================

# %%
# Test a query that compares two products
await ask_adaptive_rag("battery life for zenithbook 11 vs ultrapook 14 pro")
# Out:
# ====================================================================================================
# ADAPTIVE RAG QUERY: battery life for zenithbook 11 vs ultrapook 14 pro
# ====================================================================================================
# Query Decomposition Analysis:
#   Needs Decomposition: True
#   Sub-queries: ['What is the battery life of the ZenithBook 11?', 'What is the battery life of the UltraBook 14 Pro?']
#   Execution Plan: parallel
#   Reasoning: The query compares two distinct products, which falls under the rule to decompose queries that ask about multiple products. Each sub-query is independent and can be answered separately, so they should be executed in parallel.
#
# Executing 2 queries in parallel
#
# ================================================================================
# Parallel Query Processing
# ================================================================================
#
# --- Task: What is the battery life of the ZenithBook 11? ---
#   [0.00s] Starting processing for query: What is the battery life of the ZenithBook 11?
#   [0.00s] Skipping query rewrite for: What is the battery life of the ZenithBook 11?
#   [2.00s] Routing query: What is the battery life of the ZenithBook 11?
#   [2.00s] Reasoning: The query asks for a product specification (battery life) of a specific TechMart product, ZenithBook 11. Product specs belong in the catalog collection.
#   [2.99s] Retrieved 5 documents from catalog
#   [2.99s]   Doc 1 [techmart_catalog.csv]: product_id: SKU232 | name: ZenithBook 11 Evo | category: Laptop | price: 1299.0 | short_desc: A slee...
#   [2.99s]   Doc 2 [techmart_catalog.csv]: product_id: SKU177 | name: ZenithBook 12 Evo | category: Laptop | price: 1299.0 | short_desc: 15.6" ...
#   [2.99s]   Doc 3 [techmart_catalog.csv]: product_id: SKU050 | name: ZenithBook 15 Evo | category: Laptop | price: 1299.0 | short_desc: 15.6" ...
#   [2.99s]   Doc 4 [techmart_catalog.csv]: product_id: SKU057 | name: ZenithBook 13 Evo | category: Laptop | price: 1299.0 | short_desc: Sleek ...
#   [2.99s]   Doc 5 [techmart_catalog.csv]: product_id: SKU164 | name: ZenithBook Air 13 | category: Laptop | price: 1199.0 | short_desc: Ultra-...
#   [2.99s] Evaluating 5 documents for query: What is the battery life of the ZenithBook 11?
#   [2.99s] Evaluating 5 documents for query: What is the battery life of the ZenithBook 11?
#   [11.62s] ✓ Relevant doc: The document is about the ZenithBook 11 family and explicitly lists battery_hrs as 13, which directly answers the battery life question.
#   [11.62s] ✗ Irrelevant doc: The document is for ZenithBook 12 Evo, which appears to be a different model line than the queried ZenithBook 11. Although both are ZenithBook laptops, this document does not provide battery life for the ZenithBook 11 specifically.
#   [11.62s] ✗ Irrelevant doc: The document is for the ZenithBook 15 Evo, while the query asks about the ZenithBook 11. These appear to be different model families/sizes, so the battery life shown here does not directly answer the query.
#   [11.62s] ✓ Relevant doc: The document is for a ZenithBook laptop in the same product family, and it includes a battery life spec (13 hours). Even though it is the ZenithBook 13 Evo rather than the ZenithBook 11, it can still help answer a battery-life question about the product line.
#   [11.62s] ✓ Relevant doc: The document is for a ZenithBook laptop in the same product family and includes battery life information (15 hours), which could help answer a battery-life query even though it is the Air 13 variant rather than the ZenithBook 11.
#   [11.62s] Document evaluation complete: 3/5 relevant
#   [11.62s] Query Quality Assessment:
#   [11.62s] Relevant docs: 3/5
#   [11.62s] Found 3 relevant docs, no retry needed
#   [11.62s] No rewrite needed or found relevant documents, proceeding to generation
#   [11.62s] Generating answer for subquery: What is the battery life of the ZenithBook 11?
#   [12.81s] Generated subquery answer: The **ZenithBook 11 Evo** has a **battery life of 13 hours**.
#   [12.81s] Completed processing for query: What is the battery life of the ZenithBook 11?
#
# --- Task: What is the battery life of the UltraBook 14 Pro? ---
#   [0.00s] Starting processing for query: What is the battery life of the UltraBook 14 Pro?
#   [0.00s] Skipping query rewrite for: What is the battery life of the UltraBook 14 Pro?
#   [2.99s] Routing query: What is the battery life of the UltraBook 14 Pro?
#   [2.99s] Reasoning: This query asks for a product specification (battery life) for a specific TechMart product, UltraBook 14 Pro. Product specs and details belong in the catalog collection.
#   [3.45s] Retrieved 5 documents from catalog
#   [3.45s]   Doc 1 [techmart_catalog.csv]: product_id: SKU001 | name: UltraBook Pro 14 Laptop | category: Laptop | price: 1499.0 | short_desc: ...
#   [3.45s]   Doc 2 [techmart_catalog.csv]: product_id: SKU164 | name: ZenithBook Air 13 | category: Laptop | price: 1199.0 | short_desc: Ultra-...
#   [3.45s]   Doc 3 [techmart_catalog.csv]: product_id: SKU057 | name: ZenithBook 13 Evo | category: Laptop | price: 1299.0 | short_desc: Sleek ...
#   [3.45s]   Doc 4 [techmart_catalog.csv]: product_id: SKU177 | name: ZenithBook 12 Evo | category: Laptop | price: 1299.0 | short_desc: 15.6" ...
#   [3.45s]   Doc 5 [techmart_catalog.csv]: product_id: SKU232 | name: ZenithBook 11 Evo | category: Laptop | price: 1299.0 | short_desc: A slee...
#   [3.45s] Evaluating 5 documents for query: What is the battery life of the UltraBook 14 Pro?
#   [3.45s] Evaluating 5 documents for query: What is the battery life of the UltraBook 14 Pro?
#   [18.45s] ✓ Relevant doc: The document describes the UltraBook Pro 14 laptop and explicitly states its battery provides up to 12 hours of real-world use, which answers the battery life question.
#   [18.45s] ✗ Irrelevant doc: The document is for the ZenithBook Air 13, which is a different product line from the UltraBook 14 Pro. Although it includes battery life information, it does not help answer the query about the UltraBook 14 Pro.
#   [18.45s] ✗ Irrelevant doc: The document is for the ZenithBook 13 Evo, which is a different product line from the UltraBook 14 Pro. Although it includes battery life, it does not help answer the query about the UltraBook 14 Pro.
#   [18.45s] ✗ Irrelevant doc: The document is for ZenithBook 12 Evo, which is a different product name and family from the UltraBook 14 Pro mentioned in the query. Although it includes battery life information, it does not appear to be about the queried product.
#   [18.45s] ✗ Irrelevant doc: The document is for ZenithBook 11 Evo, which is a different product line from the queried UltraBook 14 Pro. Although it includes battery life, it does not help answer the specific query about the UltraBook 14 Pro.
#   [18.45s] Document evaluation complete: 1/5 relevant
#   [18.45s] Query Quality Assessment:
#   [18.45s] Relevant docs: 1/5
#   [18.45s] Found 1 relevant docs, no retry needed
#   [18.45s] No rewrite needed or found relevant documents, proceeding to generation
#   [18.46s] Generating answer for subquery: What is the battery life of the UltraBook 14 Pro?
#   [19.46s] Generated subquery answer: The UltraBook Pro 14 has a battery life of up to **12 hours** of real-world use.
#   [19.46s] Completed processing for query: What is the battery life of the UltraBook 14 Pro?
# ================================================================================
#
# ================================================================================
# Query Processing Summary:
#   Total queries processed: 2
#   Total documents retrieved: 4
#   Execution strategy: parallel
# ================================================================================
# Generating final answer with 4 total documents
# Generated final answer
#
# ====================================================================================================
# FINAL ANSWER:
# ====================================================================================================
# Here’s the battery life comparison from the catalog:
#
# - **ZenithBook 11 Evo**: **13 hours**
# - **UltraBook Pro 14 Laptop**: **12 hours**
#
# ### Quick takeaway
# The **ZenithBook 11 Evo** has **slightly better battery life** than the UltraBook Pro 14 — by about **1 hour**.
#
# If you want, I can also compare other specs like **weight, display, CPU, or price** between the two.
# ====================================================================================================
# Query processing completed successfully!
# ====================================================================================================
# Query Decomposition Analysis:
#   Needs Decomposition: True
#   Sub-queries: ['battery life for zenithbook 11', 'battery life for ultrapook 14 pro']
#   Execution Plan: parallel
#   Reasoning: The query compares two distinct products and asks for the battery life of each. These are independent sub-queries that can be answered separately and then compared.
#
# Executing 2 queries in parallel
# ================================================================================
# Parallel Query Processing
# ================================================================================
#
# --- Task: battery life for zenithbook 11 ---
#   [0.00s] Starting processing for query: battery life for zenithbook 11
#   [0.00s] Skipping query rewrite for: battery life for zenithbook 11
#   [1.24s] Routing query: battery life for zenithbook 11
#   [1.24s] Reasoning: The query asks for battery life of a specific product model (ZenithBook 11), which is product specification information best answered from the catalog.
#   [1.81s] Retrieved 5 documents from catalog
#   [1.81s]   Doc 1 [techmart_catalog.csv]: product_id: SKU232 | name: ZenithBook 11 Evo | category: Laptop | price: 1299.0 | short_desc: A slee...
#   [1.81s]   Doc 2 [techmart_catalog.csv]: product_id: SKU177 | name: ZenithBook 12 Evo | category: Laptop | price: 1299.0 | short_desc: 15.6" ...
#   [1.81s]   Doc 3 [techmart_catalog.csv]: product_id: SKU050 | name: ZenithBook 15 Evo | category: Laptop | price: 1299.0 | short_desc: 15.6" ...
#   [1.81s]   Doc 4 [techmart_catalog.csv]: product_id: SKU057 | name: ZenithBook 13 Evo | category: Laptop | price: 1299.0 | short_desc: Sleek ...
#   [1.81s]   Doc 5 [techmart_catalog.csv]: product_id: SKU106 | name: ZenithBook 15 Evo | category: Laptop | price: 1299.0 | short_desc: Sleek ...
#   [1.82s] Evaluating 5 documents for query: battery life for zenithbook 11
#   [1.82s] Evaluating 5 documents for query: battery life for zenithbook 11
#   [3.58s] ✓ Relevant doc: The document is about the ZenithBook 11 family and explicitly includes a battery specification ('battery_hrs': 13), which directly helps answer a query about battery life for ZenithBook 11.
#   [3.58s] ✓ Relevant doc: The document is for a ZenithBook model in the same product family and includes battery life information (12 hours), which can help answer a query about battery life for ZenithBook 11.
#   [3.58s] ✗ Irrelevant doc: The query asks about the battery life for ZenithBook 11, but the document is for ZenithBook 15 Evo, a different model in the ZenithBook family. While it includes battery life information, it is not clearly the same product line variant as ZenithBook 11, so it is not directly relevant.
#   [3.58s] ✗ Irrelevant doc: The document is for ZenithBook 13 Evo, while the query asks about battery life for ZenithBook 11. Although they share the ZenithBook family name, the model number differs enough that this appears to be a different product variant, so it is not clearly answering the query.
#   [3.58s] ✓ Relevant doc: The document is for a ZenithBook laptop and includes battery life information (13 hours), which helps answer a query about battery life for a ZenithBook 11. Even though the exact model differs, it appears to be the same product family.
#   [3.58s] Document evaluation complete: 3/5 relevant
#   [3.58s] Query Quality Assessment:
#   [3.58s] Relevant docs: 3/5
#   [3.58s] Found 3 relevant docs, no retry needed
#   [3.58s] No rewrite needed or found relevant documents, proceeding to generation
#   [3.58s] Generating answer for subquery: battery life for zenithbook 11
#   [4.78s] Generated subquery answer: The **ZenithBook 11 Evo** has an estimated **battery life of 13 hours**. It’s listed as having **“all-day battery”** in the description, with a **battery_hrs** spec of **13**.
#   [4.78s] Completed processing for query: battery life for zenithbook 11
#
# --- Task: battery life for ultrapook 14 pro ---
#   [0.00s] Starting processing for query: battery life for ultrapook 14 pro
#   [0.00s] Skipping query rewrite for: battery life for ultrapook 14 pro
#   [1.73s] Routing query: battery life for ultrapook 14 pro
#   [1.73s] Reasoning: The query asks about battery life for a specific product model, which is product specification information best found in the catalog.
#   [2.08s] Retrieved 5 documents from catalog
#   [2.08s]   Doc 1 [techmart_catalog.csv]: product_id: SKU001 | name: UltraBook Pro 14 Laptop | category: Laptop | price: 1499.0 | short_desc: ...
#   [2.08s]   Doc 2 [techmart_catalog.csv]: product_id: SKU057 | name: ZenithBook 13 Evo | category: Laptop | price: 1299.0 | short_desc: Sleek ...
#   [2.08s]   Doc 3 [techmart_catalog.csv]: product_id: SKU254 | name: AeroLite 15 Slim Laptop | category: Laptop | price: 1249.0 | short_desc: ...
#   [2.08s]   Doc 4 [techmart_catalog.csv]: product_id: SKU232 | name: ZenithBook 11 Evo | category: Laptop | price: 1299.0 | short_desc: A slee...
#   [2.08s]   Doc 5 [techmart_catalog.csv]: product_id: SKU177 | name: ZenithBook 12 Evo | category: Laptop | price: 1299.0 | short_desc: 15.6" ...
#   [2.08s] Evaluating 5 documents for query: battery life for ultrapook 14 pro
#   [2.08s] Evaluating 5 documents for query: battery life for ultrapook 14 pro
#   [3.60s] ✓ Relevant doc: The document is for the UltraBook Pro 14 laptop and explicitly states its battery capacity and battery life (72 Wh, up to 12 hours), which directly helps answer the query about battery life for an ultrapook/ultrabook 14 pro.
#   [3.60s] ✗ Irrelevant doc: The document is about a different laptop model, ZenithBook 13 Evo, not an Ultrapook 14 Pro. While it includes battery life specs, the product line and screen size differ, so it is unlikely to answer a query about the Ultrapook 14 Pro specifically.
#   [3.60s] ✗ Irrelevant doc: The query asks about battery life for the Ultrapook 14 Pro, but the document is for a different product line: AeroLite 15 Slim Laptop. Although it lists battery life, it does not appear to be the same family or a related variant.
#   [3.60s] ✗ Irrelevant doc: The document is about a ZenithBook 11 Evo laptop, which is a different product line from the queried Ultrapook 14 Pro. Although it includes battery life information, it does not appear to be the same family or a closely related variant.
#   [3.60s] ✗ Irrelevant doc: The query asks about battery life for an 'ultrapook 14 pro', but the document is for a different product, 'ZenithBook 12 Evo,' with different naming and specs. Although it includes a battery life value, it appears to be a separate laptop model rather than the same product family.
#   [3.60s] Document evaluation complete: 1/5 relevant
#   [3.60s] Query Quality Assessment:
#   [3.60s] Relevant docs: 1/5
#   [3.60s] Found 1 relevant docs, no retry needed
#   [3.60s] No rewrite needed or found relevant documents, proceeding to generation
#   [3.60s] Generating answer for subquery: battery life for ultrapook 14 pro
#   [4.82s] Generated subquery answer: The **UltraBook Pro 14 Laptop** has a **72 Wh battery** and is rated for **up to 12 hours of real-world use**.
#   [4.82s] Completed processing for query: battery life for ultrapook 14 pro
# ================================================================================
#
# ================================================================================
# Query Processing Summary:
#   Total queries processed: 2
#   Total documents retrieved: 4
#   Execution strategy: parallel
# ================================================================================
# Generating final answer with 4 total documents
# Generated final answer
#
# ====================================================================================================
# FINAL ANSWER:
# ====================================================================================================
# Here’s a battery-life comparison between the two laptops based on the catalog data:
#
# - **ZenithBook 11 Evo** — **up to 13 hours** of battery life
# - **UltraBook Pro 14 Laptop** — **up to 12 hours** of battery life
#
# ### Quick takeaway
# The **ZenithBook 11 Evo lasts about 1 hour longer** than the **UltraBook Pro 14** on paper.
#
# ### Notes
# - The **ZenithBook 11 Evo** is listed with **13 hours** of battery life and weighs **1.35 kg**.
# - The **UltraBook Pro 14** is listed with **12 hours** of real-world use and weighs **1.2 kg**.
#
# If you want, I can also compare them by **price, display, weight, or ports**.
# ====================================================================================================
# Query processing completed successfully!
# ====================================================================================================

# %% [markdown]
# ## Interactive Testing
#
# Try your own complex queries to see how the adaptive system handles them. The system will automatically analyze whether decomposition is needed and execute the appropriate strategy.

# %%
# Try your own query here!
your_question = ""
# await ask_adaptive_rag(your_question)

# %% [markdown]
# ## Comparison: Adaptive RAG vs Router RAG
#
# Let's compare how Adaptive RAG improves upon Router RAG:
#
# ### Adaptive RAG Advantages:
#
# 1. **Query Decomposition**: Automatically breaks complex multi-part questions into manageable sub-queries
# 2. **Context-Aware Sequential Processing**: Later sub-queries are enhanced with results from earlier ones
# 3. **Self-Correction**: Automatically rewrites queries when no relevant documents are found
# 4. **Quality Evaluation**: Documents are graded for relevance before answer generation
# 5. **Execution Optimization**: Parallel execution for independent sub-queries, sequential for dependent ones
# 6. **Multi-Collection Search**: Single queries can search across multiple domains simultaneously
#
# ### When Adaptive RAG Excels:
#
# - **Multi-Part Questions**: "What laptops do you have and what are your return policies?"
# - **Sequential Dependencies**: "Find the best mouse, then check if it has issues" → Enhanced second query with specific product
# - **Comparison Queries**: "Battery life for ZenithBook vs UltraBook" → Parallel sub-queries for each product
# - **Vague Queries**: "Fast thing" → Automatic rewriting to "high performance laptop with fast processor"
# - **Mixed Domain Queries**: Product questions + technical troubleshooting in one query
#
# ### Remaining Challenges:
#
# - **Increased Complexity**: More components and potential failure points
# - **Higher Latency**: Multiple sub-query processing takes longer than single routing
# - **API Cost**: More LLM calls for decomposition, evaluation, and potential rewrites
# - **Decomposition Accuracy**: Incorrect query splitting can lead to suboptimal results
#
# ### Architecture Highlights:
#
# - **Subgraph Design**: Each sub-query gets full routing → retrieval → evaluation → generation treatment
# - **State Management**: Clean flag-based retry logic prevents infinite loops
# - **Context Propagation**: Sequential queries build upon previous findings for targeted retrieval
#
# This represents the most sophisticated RAG system, ideal for complex applications requiring high-quality answers over speed optimization.
